# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional, ConvLSTM1D

# %%
df = pd.read_csv("C:/AI_study/abalone.csv")
df
# Out:
#         id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0        0   M   0.455     0.365   0.095        0.5140          0.2245
# 1        1   M   0.350     0.265   0.090        0.2255          0.0995
# 2        2   F   0.530     0.420   0.135        0.6770          0.2565
# 3        3   M   0.440     0.365   0.125        0.5160          0.2155
# 4        4   I   0.330     0.255   0.080        0.2050          0.0895
# ...    ...  ..     ...       ...     ...           ...             ...
# 4172  4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173  4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174  4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175  4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176  4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 10 columns]

# %%
# 데이터 정보 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              4177 non-null   int64
#  1   Sex             4177 non-null   object
#  2   Length          4177 non-null   float64
#  3   Diameter        4177 non-null   float64
#  4   Height          4177 non-null   float64
#  5   Whole_weight    4177 non-null   float64
#  6   Shucked_weight  4177 non-null   float64
#  7   Viscera_weight  4177 non-null   float64
#  8   Shell_weight    4177 non-null   float64
#  9   Rings           4177 non-null   int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 326.5+ KB

# %%
df['Sex'].value_counts()
# Out:
# Sex
# M    1528
# I    1342
# F    1307
# Name: count, dtype: int64

# %% [markdown]
# ## Features
# - id: id
# - Sex: 성별 M(수컷), F(암컷), I(유아기)
# - Length: 길이(앞에서 뒤까지, mm)
# - Diameter: 지름(길이에 수직인 방향, mm)
# - Height: 높이(껍질 포함, mm)
# - Whole_weight: 전체 무게(껍질 포함, g)
# - Shucked_weight: 무게(껍질 제거, g)
# - Viscera_weight: 전복 내장 무게(g)
# - Shell_weight: 건조 후 껍질 무게(g)
# - Rings: 나선(전복의 나이 추정, 나이 = Rings + 1.5) - label

# %% [markdown]
# - 현재 Features 중 id의 경우는 단순히 0 ~ 4176까지 나열한 것이므로 필요 없음
# - Sex의 경우 object형으로 M, F, I를 값으로 가지기 때문에 EDA하고 모델에 넣기 위해 Label Encoding이 필요

# %%
# 필요 없는 Feature인 id 제거
df = df.drop('id', axis=1)
df
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
# Sex 분포 시각화
sns.countplot(data=df, x="Sex", hue="Sex", palette=["#1f77b4", "#ff7f0e", "#2ca02c"])
plt.xlabel("Sex")
plt.ylabel("Count")
plt.title("Sex Distribution")

plt.show()

# %%
# Sex 피처에 Label Encoding 적용

from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
le = LabelEncoder()

df['Sex_encoded'] = le.fit_transform(df['Sex'])

df = df.drop('Sex', axis=1)
df.insert(0, 'Sex_encoded', df.pop('Sex_encoded'))

# 결과 확인
print(df)
# Out:
#       Sex_encoded  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0               2   0.455     0.365   0.095        0.5140          0.2245
# 1               2   0.350     0.265   0.090        0.2255          0.0995
# 2               0   0.530     0.420   0.135        0.6770          0.2565
# 3               2   0.440     0.365   0.125        0.5160          0.2155
# 4               1   0.330     0.255   0.080        0.2050          0.0895
# ...           ...     ...       ...     ...           ...             ...
# 4172            0   0.565     0.450   0.165        0.8870          0.3700
# 4173            2   0.590     0.440   0.135        0.9660          0.4390
# 4174            2   0.600     0.475   0.205        1.1760          0.5255
# 4175            0   0.625     0.485   0.150        1.0945          0.5310
# 4176            2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.describe()
# Out:
#        Sex_encoded       Length     Diameter       Height  Whole_weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked_weight  Viscera_weight  Shell_weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# min          0.001000        0.000500      0.001500     1.000000
# 25%          0.186000        0.093500      0.130000     8.000000
# 50%          0.336000        0.171000      0.234000     9.000000
# 75%          0.502000        0.253000      0.329000    11.000000
# max          1.488000        0.760000      1.005000    29.000000

# %%
# 데이터 결측치 확인
df.isnull().sum()
# Out:
# Sex_encoded       0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
df['Rings'].value_counts()
# Out:
# Rings
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 1       1
# 26      1
# 29      1
# 2       1
# 25      1
# Name: count, dtype: int64

# %%
#상관관계 히트맵 생성
#상관 관계 행렬
df_corr=df.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %% [markdown]
# ## Target인 Rings와 가장 높은 상관 관계를 맺는 feature
# - Shell_weight(0.63)

# %% [markdown]
# ## Target인 Rings와 비교적 낮은 상관 관계를 맺는 features
# - Sex_encoded(-0.035)
# - Shucked_weight(0.42)
# - Visvera_weight(0.5)

# %% [markdown]
# - Sex_encoded의 경우 매우 낮은 상관 관계를 갖고 있기 때문에 추후에 삭제 가능

# %%
df.hist(bins=50, figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'Sex_encoded'}>,
#         <Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Diameter'}>],
#        [<Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Whole_weight'}>,
#         <Axes: title={'center': 'Shucked_weight'}>],
#        [<Axes: title={'center': 'Viscera_weight'}>,
#         <Axes: title={'center': 'Shell_weight'}>,
#         <Axes: title={'center': 'Rings'}>]], dtype=object)

# %%
# Rings와 Shell_weight 관계
plt.scatter(df['Rings'], df['Shell_weight'])
plt.xlabel('Rings')
plt.ylabel('Shell_weight')

plt.show()

# %%
# 각 열에서 0인 값의 개수를 확인
zero_values_count = (df == 0).sum()

# 결과 출력
print(zero_values_count)
# Out:
# Sex_encoded       1307
# Length               0
# Diameter             0
# Height               2
# Whole_weight         0
# Shucked_weight       0
# Viscera_weight       0
# Shell_weight         0
# Rings                0
# dtype: int64

# %% [markdown]
# #### Height(높이)가 0 값이 나오는 것은 이상치로 판단

# %%
# 이상치의 개수가 적은 Glucose, BloodPressure, BMI의 경우 이상치 제거
print("제거 전 데이터 개수: ", len(df))
df = df[(df['Height'] != 0)]
print("제거 후 데이터 개수: ", len(df))
# Out:
# 제거 전 데이터 개수:  4177
# 제거 후 데이터 개수:  4175

# %% [markdown]
# 2개의 데이터 제거

# %%
# Rings 시각화
sns.countplot(data = df, x="Rings")
plt.xlabel("Rings")
plt.ylabel("Count")
plt.title("Abalone")

plt.show()

# %% [markdown]
# ### Rings는 연속적인 수치 데이터를 가지므로 Classification 문제로 다루기 위해선 범주형 값으로 변환하는 과정이 필요

# %%
# 분위수 기반으로 구간 나누기
Rings_binned, bins = pd.qcut(df['Rings'], q=3, labels=['Young', 'Middle-aged', 'Old'], retbins=True)

# 구간 경계값 출력
print("구간 경계값: ", bins)

# 새로운 범주형 피처 생성
df['Rings_binned'] = Rings_binned

# 결과 확인
print(df[['Rings', 'Rings_binned']].head())
# Out:
# 구간 경계값:  [ 1.  8. 11. 29.]
#    Rings Rings_binned
# 0     15          Old
# 1      7        Young
# 2      9  Middle-aged
# 3     10  Middle-aged
# 4      7        Young

# %% [markdown]
# ### pd.qcut 함수를 통해 각 구간에 비슷한 개수의 샘플이 있도록 분위수를 기준으로 구간을 나눔
# - 구간 경계 값을 출력한 결과 (1 ~ 7, 8 ~ 10, 11 ~ 29)의 세 구간('Young', 'Middle-aged', 'Old')으로 나눠진 것을 확인할 수 있음

# %%
df['Rings_binned'].value_counts()
# Out:
# Rings_binned
# Middle-aged    1810
# Young          1405
# Old             960
# Name: count, dtype: int64

# %% [markdown]
# ### 분위 수를 기반으로 나눴지만 Middle-aged와 Old 간의 차이가 두 배정도 나는 것을 확인할 수 있음
# - 추후 OverSampling, UnderSampling 등을 적용할 수 있음

# %%
df = df.drop('Rings', axis=1)
df
# Out:
#       Sex_encoded  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0               2   0.455     0.365   0.095        0.5140          0.2245
# 1               2   0.350     0.265   0.090        0.2255          0.0995
# 2               0   0.530     0.420   0.135        0.6770          0.2565
# 3               2   0.440     0.365   0.125        0.5160          0.2155
# 4               1   0.330     0.255   0.080        0.2050          0.0895
# ...           ...     ...       ...     ...           ...             ...
# 4172            0   0.565     0.450   0.165        0.8870          0.3700
# 4173            2   0.590     0.440   0.135        0.9660          0.4390
# 4174            2   0.600     0.475   0.205        1.1760          0.5255
# 4175            0   0.625     0.485   0.150        1.0945          0.5310
# 4176            2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight Rings_binned
# 0             0.1010        0.1500          Old
# 1             0.0485        0.0700        Young
# 2             0.1415        0.2100  Middle-aged
# 3             0.1140        0.1550  Middle-aged
# 4             0.0395        0.0550        Young
# ...              ...           ...          ...
# 4172          0.2390        0.2490  Middle-aged
# 4173          0.2145        0.2605  Middle-aged
# 4174          0.2875        0.3080  Middle-aged
# 4175          0.2610        0.2960  Middle-aged
# 4176          0.3765        0.4950          Old
#
# [4175 rows x 9 columns]

# %%
import numpy as np
from collections import Counter

# split_sequence 함수 (수정됨)
def split_sequence(sequence, labels, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence)-1:
            break
        
        # sequence에서 n_steps 크기만큼 데이터 추출
        seq_x = sequence[i:end_ix]
        
        # labels에서 n_steps 크기만큼 레이블 추출
        seq_y = labels[i:end_ix]
        
        # seq_y에서 가장 많이 등장한 레이블 선택
        most_common_label = Counter(seq_y).most_common(1)[0][0]
        
        # X와 y에 추가
        X.append(seq_x)
        y.append(most_common_label)
    
    return np.array(X), np.array(y)

# %%
# 실제 데이터 적용
sequence = df.drop('Rings_binned', axis=1).values  # 수치형 데이터
labels = df['Rings_binned'].values  # 범주형 레이블 'Rings_binned'

# 시퀀스 분리
n_steps = 7
X, y = split_sequence(sequence, labels, n_steps)

# %%
# df의 상위 14개 행 출력
df.head(14)
# Out:
#     Sex_encoded  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0             2   0.455     0.365   0.095        0.5140          0.2245
# 1             2   0.350     0.265   0.090        0.2255          0.0995
# 2             0   0.530     0.420   0.135        0.6770          0.2565
# 3             2   0.440     0.365   0.125        0.5160          0.2155
# 4             1   0.330     0.255   0.080        0.2050          0.0895
# 5             1   0.425     0.300   0.095        0.3515          0.1410
# 6             0   0.530     0.415   0.150        0.7775          0.2370
# 7             0   0.545     0.425   0.125        0.7680          0.2940
# 8             2   0.475     0.370   0.125        0.5095          0.2165
# 9             0   0.550     0.440   0.150        0.8945          0.3145
# 10            0   0.525     0.380   0.140        0.6065          0.1940
# 11            2   0.430     0.350   0.110        0.4060          0.1675
# 12            2   0.490     0.380   0.135        0.5415          0.2175
# 13            0   0.535     0.405   0.145        0.6845          0.2725
#
#     Viscera_weight  Shell_weight Rings_binned
# 0           0.1010         0.150          Old
# 1           0.0485         0.070        Young
# 2           0.1415         0.210  Middle-aged
# 3           0.1140         0.155  Middle-aged
# 4           0.0395         0.055        Young
# 5           0.0775         0.120        Young
# 6           0.1415         0.330          Old
# 7           0.1495         0.260          Old
# 8           0.1125         0.165  Middle-aged
# 9           0.1510         0.320          Old
# 10          0.1475         0.210          Old
# 11          0.0810         0.135  Middle-aged
# 12          0.0950         0.190  Middle-aged
# 13          0.1710         0.205  Middle-aged

# %% [markdown]
# n_steps를 7로 설정했기 때문에 7개씩 묶었을 때 최빈 값이 label이 됨
# - 0~7 index : Young(3회)
# - 1~9 index : Young(3회)
# - 2~10 index : Middle-aged(3회)
# - 3~11 index : Old(3회)

# %%
print(X)
print(y)
# Out:
# [[[2.     0.455  0.365  ... 0.2245 0.101  0.15  ]
#   [2.     0.35   0.265  ... 0.0995 0.0485 0.07  ]
#   [0.     0.53   0.42   ... 0.2565 0.1415 0.21  ]
#   ...
#   [1.     0.33   0.255  ... 0.0895 0.0395 0.055 ]
#   [1.     0.425  0.3    ... 0.141  0.0775 0.12  ]
#   [0.     0.53   0.415  ... 0.237  0.1415 0.33  ]]
#
#  [[2.     0.35   0.265  ... 0.0995 0.0485 0.07  ]
#   [0.     0.53   0.42   ... 0.2565 0.1415 0.21  ]
#   [2.     0.44   0.365  ... 0.2155 0.114  0.155 ]
#   ...
#   [1.     0.425  0.3    ... 0.141  0.0775 0.12  ]
#   [0.     0.53   0.415  ... 0.237  0.1415 0.33  ]
#   [0.     0.545  0.425  ... 0.294  0.1495 0.26  ]]
#
#  [[0.     0.53   0.42   ... 0.2565 0.1415 0.21  ]
#   [2.     0.44   0.365  ... 0.2155 0.114  0.155 ]
#   [1.     0.33   0.255  ... 0.0895 0.0395 0.055 ]
#   ...
#   [0.     0.53   0.415  ... 0.237  0.1415 0.33  ]
#   [0.     0.545  0.425  ... 0.294  0.1495 0.26  ]
#   [2.     0.475  0.37   ... 0.2165 0.1125 0.165 ]]
#
#  ...
#
#  [[2.     0.5    0.38   ... 0.269  0.1265 0.1535]
#   [0.     0.515  0.4    ... 0.2865 0.123  0.1765]
#   [2.     0.52   0.385  ... 0.375  0.18   0.1815]
#   ...
#   [2.     0.56   0.43   ... 0.4    0.172  0.229 ]
#   [0.     0.565  0.45   ... 0.37   0.239  0.249 ]
#   [2.     0.59   0.44   ... 0.439  0.2145 0.2605]]
#
#  [[0.     0.515  0.4    ... 0.2865 0.123  0.1765]
#   [2.     0.52   0.385  ... 0.375  0.18   0.1815]
#   [2.     0.55   0.43   ... 0.3155 0.1955 0.2405]
#   ...
#   [0.     0.565  0.45   ... 0.37   0.239  0.249 ]
#   [2.     0.59   0.44   ... 0.439  0.2145 0.2605]
#   [2.     0.6    0.475  ... 0.5255 0.2875 0.308 ]]
#
#  [[2.     0.52   0.385  ... 0.375  0.18   0.1815]
#   [2.     0.55   0.43   ... 0.3155 0.1955 0.2405]
#   [2.     0.56   0.43   ... 0.4    0.172  0.229 ]
#   ...
#   [2.     0.59   0.44   ... 0.439  0.2145 0.2605]
#   [2.     0.6    0.475  ... 0.5255 0.2875 0.308 ]
#   [0.     0.625  0.485  ... 0.531  0.261  0.296 ]]]
# ['Young' 'Young' 'Middle-aged' ... 'Middle-aged' 'Middle-aged'
#  'Middle-aged']

# %% [markdown]
# y값을 출력한 결과 상위 3개가 Young, Young, Middle-aged로 예상한 대로 split_sequence가 잘 적용된 것을 볼 수 있음

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=32)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train, random_state=32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((2667, 7, 8), (834, 7, 8), (2667,), (834,), (667, 7, 8), (667,))

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)
y_test_encoded = label_encoder.transform(y_test)

# %%
from tensorflow.keras.utils import to_categorical

trainy_one_hot = to_categorical(y_train_encoded)
val_one_hot = to_categorical(y_val_encoded)
testy_one_hot = to_categorical(y_test_encoded)

# %% [markdown]
# ## DL Model (CNN)

# %%
n_timesteps, n_features = X_train.shape[1], X_train.shape[2]

# %%
# Model 3
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=2, activation='relu', input_shape=(n_timesteps, n_features)))
model.add((Dropout(0.5)))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add((Dropout(0.5)))
model.add(Conv1D(filters=32, kernel_size=4, activation='relu', padding='same'))
model.add((Dropout(0.5)))
model.add(Flatten())
model.add(Dense(16, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 6, 32)             544
#
#  dropout (Dropout)           (None, 6, 32)             0
#
#  conv1d_1 (Conv1D)           (None, 6, 64)             6208
#
#  dropout_1 (Dropout)         (None, 6, 64)             0
#
#  conv1d_2 (Conv1D)           (None, 6, 32)             8224
#
#  dropout_2 (Dropout)         (None, 6, 32)             0
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 16)                3088
#
#  dense_1 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 18,115
# Trainable params: 18,115
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

train_epochs = 50
history = model.fit(X_train, trainy_one_hot, epochs=train_epochs, batch_size=batch_size, validation_data=(X_val, val_one_hot), verbose=True, shuffle=True)
# Out:
# Epoch 1/50
# 167/167 [==============================] - 3s 4ms/step - loss: 1.0046 - accuracy: 0.4829 - val_loss: 0.8847 - val_accuracy: 0.6147
# Epoch 2/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.8767 - accuracy: 0.6149 - val_loss: 0.8036 - val_accuracy: 0.6297
# Epoch 3/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.8278 - accuracy: 0.6247 - val_loss: 0.7832 - val_accuracy: 0.6252
# Epoch 4/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.8073 - accuracy: 0.6310 - val_loss: 0.7691 - val_accuracy: 0.6282
# Epoch 5/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.7948 - accuracy: 0.6310 - val_loss: 0.7660 - val_accuracy: 0.6312
# Epoch 6/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.7752 - accuracy: 0.6325 - val_loss: 0.7506 - val_accuracy: 0.6417
# Epoch 7/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.7672 - accuracy: 0.6385 - val_loss: 0.7487 - val_accuracy: 0.6327
# Epoch 8/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.7498 - accuracy: 0.6442 - val_loss: 0.7220 - val_accuracy: 0.6432
# Epoch 9/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.7456 - accuracy: 0.6423 - val_loss: 0.7269 - val_accuracy: 0.6507
# Epoch 10/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.7291 - accuracy: 0.6550 - val_loss: 0.6943 - val_accuracy: 0.6612
# Epoch 11/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.7012 - accuracy: 0.6712 - val_loss: 0.6543 - val_accuracy: 0.7121
# Epoch 12/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.6804 - accuracy: 0.6903 - val_loss: 0.6229 - val_accuracy: 0.7151
# Epoch 13/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.6604 - accuracy: 0.7023 - val_loss: 0.5938 - val_accuracy: 0.7391
# Epoch 14/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.6314 - accuracy: 0.7218 - val_loss: 0.6132 - val_accuracy: 0.7331
# Epoch 15/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.6183 - accuracy: 0.7192 - val_loss: 0.5552 - val_accuracy: 0.7571
# Epoch 16/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5826 - accuracy: 0.7454 - val_loss: 0.5456 - val_accuracy: 0.7571
# Epoch 17/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5992 - accuracy: 0.7447 - val_loss: 0.5571 - val_accuracy: 0.7616
# Epoch 18/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5776 - accuracy: 0.7537 - val_loss: 0.5345 - val_accuracy: 0.7496
# Epoch 19/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.5770 - accuracy: 0.7499 - val_loss: 0.5466 - val_accuracy: 0.7766
# Epoch 20/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.5712 - accuracy: 0.7439 - val_loss: 0.5227 - val_accuracy: 0.7661
# Epoch 21/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.5478 - accuracy: 0.7645 - val_loss: 0.5270 - val_accuracy: 0.7676
# Epoch 22/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5508 - accuracy: 0.7563 - val_loss: 0.5342 - val_accuracy: 0.7646
# Epoch 23/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5470 - accuracy: 0.7612 - val_loss: 0.5256 - val_accuracy: 0.7526
# Epoch 24/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5352 - accuracy: 0.7683 - val_loss: 0.5547 - val_accuracy: 0.7556
# Epoch 25/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5368 - accuracy: 0.7642 - val_loss: 0.5062 - val_accuracy: 0.7796
# Epoch 26/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5342 - accuracy: 0.7747 - val_loss: 0.5020 - val_accuracy: 0.7631
# Epoch 27/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5239 - accuracy: 0.7803 - val_loss: 0.5035 - val_accuracy: 0.7706
# Epoch 28/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.5234 - accuracy: 0.7713 - val_loss: 0.5063 - val_accuracy: 0.7646
# Epoch 29/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.5330 - accuracy: 0.7724 - val_loss: 0.4982 - val_accuracy: 0.7676
# Epoch 30/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5179 - accuracy: 0.7743 - val_loss: 0.5156 - val_accuracy: 0.7616
# Epoch 31/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5176 - accuracy: 0.7840 - val_loss: 0.5973 - val_accuracy: 0.7286
# Epoch 32/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5111 - accuracy: 0.7702 - val_loss: 0.4951 - val_accuracy: 0.7766
# Epoch 33/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5063 - accuracy: 0.7867 - val_loss: 0.4970 - val_accuracy: 0.7721
# Epoch 34/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5148 - accuracy: 0.7750 - val_loss: 0.4915 - val_accuracy: 0.7706
# Epoch 35/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.4997 - accuracy: 0.7825 - val_loss: 0.4938 - val_accuracy: 0.7751
# Epoch 36/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.5092 - accuracy: 0.7795 - val_loss: 0.4855 - val_accuracy: 0.7811
# Epoch 37/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.5229 - accuracy: 0.7735 - val_loss: 0.4813 - val_accuracy: 0.7811
# Epoch 38/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.5037 - accuracy: 0.7840 - val_loss: 0.5019 - val_accuracy: 0.7616
# Epoch 39/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.4839 - accuracy: 0.7844 - val_loss: 0.5256 - val_accuracy: 0.7526
# Epoch 40/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.5012 - accuracy: 0.7814 - val_loss: 0.4782 - val_accuracy: 0.7871
# Epoch 41/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.4959 - accuracy: 0.7833 - val_loss: 0.4748 - val_accuracy: 0.7856
# Epoch 42/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.7780 - val_loss: 0.4704 - val_accuracy: 0.7871
# Epoch 43/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.4926 - accuracy: 0.7904 - val_loss: 0.4848 - val_accuracy: 0.7811
# Epoch 44/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.4989 - accuracy: 0.7788 - val_loss: 0.4699 - val_accuracy: 0.7871
# Epoch 45/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.4904 - accuracy: 0.7863 - val_loss: 0.4768 - val_accuracy: 0.7826
# Epoch 46/50
# 167/167 [==============================] - 1s 3ms/step - loss: 0.4881 - accuracy: 0.7957 - val_loss: 0.5226 - val_accuracy: 0.7796
# Epoch 47/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.4888 - accuracy: 0.7810 - val_loss: 0.4684 - val_accuracy: 0.7886
# Epoch 48/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.4780 - accuracy: 0.7915 - val_loss: 0.4809 - val_accuracy: 0.7856
# Epoch 49/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.4777 - accuracy: 0.7848 - val_loss: 0.4759 - val_accuracy: 0.7931
# Epoch 50/50
# 167/167 [==============================] - 0s 3ms/step - loss: 0.4836 - accuracy: 0.7919 - val_loss: 0.4923 - val_accuracy: 0.7916

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

predy=model.predict(X_test)
predy=np.argmax(predy, axis=-1)
LABELS = ['Young', 'Middle-aged', 'Old']
cm=confusion_matrix(y_test_encoded,predy)
print(cm)
print(accuracy_score(y_test_encoded,predy))
print(f1_score(y_test_encoded,predy, average='weighted'))
print(classification_report(y_test_encoded,predy))
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 27/27 [==============================] - 0s 2ms/step
# [[311  62   6]
#  [ 28 161   3]
#  [ 76  11 176]]
# 0.7769784172661871
# 0.7777804101183827
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78       379
#            1       0.69      0.84      0.76       192
#            2       0.95      0.67      0.79       263
#
#     accuracy                           0.78       834
#    macro avg       0.80      0.78      0.77       834
# weighted avg       0.80      0.78      0.78       834
# <Axes: >

# %% [markdown]
# ### 데이터 전처리 단계에서 정확도 올리기
# - Rings와 상관관계가 비교적 낮았던 Sex_encoded, Shucked_weight 제거
# - Smote 함수를 사용한 label OverSampling

# %%
df = df.drop(['Sex_encoded'], axis=1)
df
# Out:
#       Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell_weight Rings_binned
# 0           0.1500          Old
# 1           0.0700        Young
# 2           0.2100  Middle-aged
# 3           0.1550  Middle-aged
# 4           0.0550        Young
# ...            ...          ...
# 4172        0.2490  Middle-aged
# 4173        0.2605  Middle-aged
# 4174        0.3080  Middle-aged
# 4175        0.2960  Middle-aged
# 4176        0.4950          Old
#
# [4175 rows x 8 columns]

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(df.drop('Rings_binned', axis=1), df['Rings_binned'])

# %%
y_resampled.value_counts()
# Out:
# Rings_binned
# Young          1810
# Middle-aged    1810
# Old            1810
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# y_resampled의 클래스 분포를 계산
value_counts = y_resampled.value_counts()

# 시각화
plt.figure(figsize=(8, 6))
value_counts.plot(kind='bar', color=["#1f77b4", "#ff7f0e", "#2ca02c"])  # 막대그래프 생성
plt.title('Class Distribution after Resampling')
plt.xlabel('Class Labels')
plt.ylabel('Frequency')
plt.xticks(rotation=0)  # x축 레이블 수평으로 표시
plt.show()

# %%
# 실제 데이터 적용
sequence = X_resampled.values  # 수치형 데이터
labels = y_resampled.values  # 범주형 레이블 'Rings_binned'

# 시퀀스 분리
n_steps = 7
X, y = split_sequence(sequence, labels, n_steps)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=32)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train, random_state=32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((3470, 7, 7), (1085, 7, 7), (3470,), (1085,), (868, 7, 7), (868,))

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)
y_test_encoded = label_encoder.transform(y_test)

# %%
from tensorflow.keras.utils import to_categorical

trainy_one_hot = to_categorical(y_train_encoded)
val_one_hot = to_categorical(y_val_encoded)
testy_one_hot = to_categorical(y_test_encoded)

# %%
n_timesteps, n_features = X_train.shape[1], X_train.shape[2]

# %%
# Model 3
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=2, activation='relu', input_shape=(n_timesteps, n_features)))
model.add((Dropout(0.5)))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add((Dropout(0.5)))
model.add(Conv1D(filters=32, kernel_size=4, activation='relu', padding='same'))
model.add((Dropout(0.5)))
model.add(Flatten())
model.add(Dense(16, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 6, 32)             480
#
#  dropout_3 (Dropout)         (None, 6, 32)             0
#
#  conv1d_4 (Conv1D)           (None, 6, 64)             6208
#
#  dropout_4 (Dropout)         (None, 6, 64)             0
#
#  conv1d_5 (Conv1D)           (None, 6, 32)             8224
#
#  dropout_5 (Dropout)         (None, 6, 32)             0
#
#  flatten_1 (Flatten)         (None, 192)               0
#
#  dense_2 (Dense)             (None, 16)                3088
#
#  dense_3 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 18,051
# Trainable params: 18,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

train_epochs = 50
history = model.fit(X_train, trainy_one_hot, epochs=train_epochs, batch_size=batch_size, validation_data=(X_val, val_one_hot), verbose=True, shuffle=True)
# Out:
# Epoch 1/50
# 217/217 [==============================] - 1s 4ms/step - loss: 1.0102 - accuracy: 0.4522 - val_loss: 0.9369 - val_accuracy: 0.5864
# Epoch 2/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.8407 - accuracy: 0.5599 - val_loss: 0.8296 - val_accuracy: 0.5311
# Epoch 3/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.7897 - accuracy: 0.5948 - val_loss: 0.7156 - val_accuracy: 0.7431
# Epoch 4/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.6797 - accuracy: 0.7153 - val_loss: 0.6010 - val_accuracy: 0.7419
# Epoch 5/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.5862 - accuracy: 0.7628 - val_loss: 0.5095 - val_accuracy: 0.7915
# Epoch 6/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.5341 - accuracy: 0.7931 - val_loss: 0.4910 - val_accuracy: 0.7972
# Epoch 7/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.5115 - accuracy: 0.7951 - val_loss: 0.4753 - val_accuracy: 0.8007
# Epoch 8/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4943 - accuracy: 0.7983 - val_loss: 0.4640 - val_accuracy: 0.8065
# Epoch 9/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4927 - accuracy: 0.8009 - val_loss: 0.4805 - val_accuracy: 0.7903
# Epoch 10/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4781 - accuracy: 0.8084 - val_loss: 0.4892 - val_accuracy: 0.7834
# Epoch 11/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4891 - accuracy: 0.8078 - val_loss: 0.4577 - val_accuracy: 0.8065
# Epoch 12/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4687 - accuracy: 0.8089 - val_loss: 0.4490 - val_accuracy: 0.8065
# Epoch 13/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4767 - accuracy: 0.8032 - val_loss: 0.4496 - val_accuracy: 0.8041
# Epoch 14/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4472 - accuracy: 0.8150 - val_loss: 0.4480 - val_accuracy: 0.7972
# Epoch 15/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4496 - accuracy: 0.8205 - val_loss: 0.4721 - val_accuracy: 0.8111
# Epoch 16/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4466 - accuracy: 0.8202 - val_loss: 0.4329 - val_accuracy: 0.8065
# Epoch 17/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4507 - accuracy: 0.8124 - val_loss: 0.4505 - val_accuracy: 0.8180
# Epoch 18/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4440 - accuracy: 0.8190 - val_loss: 0.4301 - val_accuracy: 0.8168
# Epoch 19/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4355 - accuracy: 0.8222 - val_loss: 0.4633 - val_accuracy: 0.7961
# Epoch 20/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4430 - accuracy: 0.8210 - val_loss: 0.4921 - val_accuracy: 0.8065
# Epoch 21/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4371 - accuracy: 0.8176 - val_loss: 0.4228 - val_accuracy: 0.8134
# Epoch 22/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4360 - accuracy: 0.8216 - val_loss: 0.4206 - val_accuracy: 0.8145
# Epoch 23/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4283 - accuracy: 0.8210 - val_loss: 0.4223 - val_accuracy: 0.8191
# Epoch 24/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4289 - accuracy: 0.8222 - val_loss: 0.4129 - val_accuracy: 0.8237
# Epoch 25/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4223 - accuracy: 0.8280 - val_loss: 0.4129 - val_accuracy: 0.8226
# Epoch 26/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4329 - accuracy: 0.8239 - val_loss: 0.4482 - val_accuracy: 0.8157
# Epoch 27/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4247 - accuracy: 0.8242 - val_loss: 0.4133 - val_accuracy: 0.8157
# Epoch 28/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4194 - accuracy: 0.8228 - val_loss: 0.4147 - val_accuracy: 0.8226
# Epoch 29/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4201 - accuracy: 0.8202 - val_loss: 0.4336 - val_accuracy: 0.8122
# Epoch 30/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4292 - accuracy: 0.8173 - val_loss: 0.4247 - val_accuracy: 0.8145
# Epoch 31/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4185 - accuracy: 0.8285 - val_loss: 0.4378 - val_accuracy: 0.8180
# Epoch 32/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4177 - accuracy: 0.8294 - val_loss: 0.4201 - val_accuracy: 0.8122
# Epoch 33/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4187 - accuracy: 0.8216 - val_loss: 0.4066 - val_accuracy: 0.8353
# Epoch 34/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4075 - accuracy: 0.8349 - val_loss: 0.4157 - val_accuracy: 0.8283
# Epoch 35/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4090 - accuracy: 0.8303 - val_loss: 0.4096 - val_accuracy: 0.8191
# Epoch 36/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4038 - accuracy: 0.8346 - val_loss: 0.4011 - val_accuracy: 0.8329
# Epoch 37/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4006 - accuracy: 0.8375 - val_loss: 0.4394 - val_accuracy: 0.8226
# Epoch 38/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4091 - accuracy: 0.8242 - val_loss: 0.3995 - val_accuracy: 0.8283
# Epoch 39/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4215 - accuracy: 0.8285 - val_loss: 0.4028 - val_accuracy: 0.8329
# Epoch 40/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.3981 - accuracy: 0.8357 - val_loss: 0.3972 - val_accuracy: 0.8399
# Epoch 41/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4087 - accuracy: 0.8282 - val_loss: 0.4139 - val_accuracy: 0.8329
# Epoch 42/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4052 - accuracy: 0.8337 - val_loss: 0.4143 - val_accuracy: 0.8214
# Epoch 43/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.3936 - accuracy: 0.8380 - val_loss: 0.4133 - val_accuracy: 0.8249
# Epoch 44/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4143 - accuracy: 0.8360 - val_loss: 0.4121 - val_accuracy: 0.8260
# Epoch 45/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.3937 - accuracy: 0.8352 - val_loss: 0.3984 - val_accuracy: 0.8364
# Epoch 46/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.3985 - accuracy: 0.8357 - val_loss: 0.4051 - val_accuracy: 0.8306
# Epoch 47/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4022 - accuracy: 0.8372 - val_loss: 0.4321 - val_accuracy: 0.8157
# Epoch 48/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.4003 - accuracy: 0.8343 - val_loss: 0.4129 - val_accuracy: 0.8237
# Epoch 49/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.3986 - accuracy: 0.8415 - val_loss: 0.4226 - val_accuracy: 0.8145
# Epoch 50/50
# 217/217 [==============================] - 1s 3ms/step - loss: 0.3968 - accuracy: 0.8305 - val_loss: 0.4082 - val_accuracy: 0.8260

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

predy=model.predict(X_test)
predy=np.argmax(predy, axis=-1)
LABELS = ['Young', 'Middle-aged', 'Old']
cm=confusion_matrix(y_test_encoded,predy)
print(cm)
print(accuracy_score(y_test_encoded,predy))
print(f1_score(y_test_encoded,predy, average='weighted'))
print(classification_report(y_test_encoded,predy))
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 34/34 [==============================] - 0s 2ms/step
# [[296  49  35]
#  [ 40 308  14]
#  [ 33  10 300]]
# 0.8331797235023042
# 0.8328419268049957
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79       380
#            1       0.84      0.85      0.84       362
#            2       0.86      0.87      0.87       343
#
#     accuracy                           0.83      1085
#    macro avg       0.83      0.83      0.83      1085
# weighted avg       0.83      0.83      0.83      1085
# <Axes: >
