# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional, ConvLSTM1D

# %%
df = pd.read_csv("C:/AI_study/abalone.csv")
df
# Out:
#         id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0        0   M   0.455     0.365   0.095        0.5140          0.2245
# 1        1   M   0.350     0.265   0.090        0.2255          0.0995
# 2        2   F   0.530     0.420   0.135        0.6770          0.2565
# 3        3   M   0.440     0.365   0.125        0.5160          0.2155
# 4        4   I   0.330     0.255   0.080        0.2050          0.0895
# ...    ...  ..     ...       ...     ...           ...             ...
# 4172  4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173  4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174  4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175  4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176  4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 10 columns]

# %%
# 데이터 정보 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              4177 non-null   int64
#  1   Sex             4177 non-null   object
#  2   Length          4177 non-null   float64
#  3   Diameter        4177 non-null   float64
#  4   Height          4177 non-null   float64
#  5   Whole_weight    4177 non-null   float64
#  6   Shucked_weight  4177 non-null   float64
#  7   Viscera_weight  4177 non-null   float64
#  8   Shell_weight    4177 non-null   float64
#  9   Rings           4177 non-null   int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 326.5+ KB

# %%
df['Sex'].value_counts()
# Out:
# Sex
# M    1528
# I    1342
# F    1307
# Name: count, dtype: int64

# %% [markdown]
# ## Features
# - id: id
# - Sex: 성별 M(수컷), F(암컷), I(유아기)
# - Length: 길이(앞에서 뒤까지, mm)
# - Diameter: 지름(길이에 수직인 방향, mm)
# - Height: 높이(껍질 포함, mm)
# - Whole_weight: 전체 무게(껍질 포함, g)
# - Shucked_weight: 무게(껍질 제거, g)
# - Viscera_weight: 전복 내장 무게(g)
# - Shell_weight: 건조 후 껍질 무게(g)
# - Rings: 나선(전복의 나이 추정, 나이 = Rings + 1.5) - label

# %% [markdown]
# - 현재 Features 중 id의 경우는 단순히 0 ~ 4176까지 나열한 것이므로 필요 없음
# - Sex의 경우 object형으로 M, F, I를 값으로 가지기 때문에 EDA하고 모델에 넣기 위해 Label Encoding이 필요

# %%
# 필요 없는 Feature인 id 제거
df = df.drop('id', axis=1)
df
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
# Sex 분포 시각화
sns.countplot(data=df, x="Sex", hue="Sex", palette=["#1f77b4", "#ff7f0e", "#2ca02c"])
plt.xlabel("Sex")
plt.ylabel("Count")
plt.title("Sex Distribution")

plt.show()

# %%
# Sex 피처에 Label Encoding 적용

from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
le = LabelEncoder()

df['Sex_encoded'] = le.fit_transform(df['Sex'])

df = df.drop('Sex', axis=1)
df.insert(0, 'Sex_encoded', df.pop('Sex_encoded'))

# 결과 확인
print(df)
# Out:
#       Sex_encoded  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0               2   0.455     0.365   0.095        0.5140          0.2245
# 1               2   0.350     0.265   0.090        0.2255          0.0995
# 2               0   0.530     0.420   0.135        0.6770          0.2565
# 3               2   0.440     0.365   0.125        0.5160          0.2155
# 4               1   0.330     0.255   0.080        0.2050          0.0895
# ...           ...     ...       ...     ...           ...             ...
# 4172            0   0.565     0.450   0.165        0.8870          0.3700
# 4173            2   0.590     0.440   0.135        0.9660          0.4390
# 4174            2   0.600     0.475   0.205        1.1760          0.5255
# 4175            0   0.625     0.485   0.150        1.0945          0.5310
# 4176            2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.describe()
# Out:
#        Sex_encoded       Length     Diameter       Height  Whole_weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked_weight  Viscera_weight  Shell_weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# min          0.001000        0.000500      0.001500     1.000000
# 25%          0.186000        0.093500      0.130000     8.000000
# 50%          0.336000        0.171000      0.234000     9.000000
# 75%          0.502000        0.253000      0.329000    11.000000
# max          1.488000        0.760000      1.005000    29.000000

# %%
# 데이터 결측치 확인
df.isnull().sum()
# Out:
# Sex_encoded       0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
df['Rings'].value_counts()
# Out:
# Rings
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 1       1
# 26      1
# 29      1
# 2       1
# 25      1
# Name: count, dtype: int64

# %%
#상관관계 히트맵 생성
#상관 관계 행렬
df_corr=df.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %% [markdown]
# ## Target인 Rings와 가장 높은 상관 관계를 맺는 feature
# - Shell_weight(0.63)

# %% [markdown]
# ## Target인 Rings와 비교적 낮은 상관 관계를 맺는 features
# - Sex_encoded(-0.035)
# - Shucked_weight(0.42)
# - Visvera_weight(0.5)

# %% [markdown]
# - Sex_encoded의 경우 매우 낮은 상관 관계를 갖고 있기 때문에 추후에 삭제 가능

# %%
df.hist(bins=50, figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'Sex_encoded'}>,
#         <Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Diameter'}>],
#        [<Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Whole_weight'}>,
#         <Axes: title={'center': 'Shucked_weight'}>],
#        [<Axes: title={'center': 'Viscera_weight'}>,
#         <Axes: title={'center': 'Shell_weight'}>,
#         <Axes: title={'center': 'Rings'}>]], dtype=object)

# %%
# Rings와 Shell_weight 관계
plt.scatter(df['Rings'], df['Shell_weight'])
plt.xlabel('Rings')
plt.ylabel('Shell_weight')

plt.show()

# %%
# 각 열에서 0인 값의 개수를 확인
zero_values_count = (df == 0).sum()

# 결과 출력
print(zero_values_count)
# Out:
# Sex_encoded       1307
# Length               0
# Diameter             0
# Height               2
# Whole_weight         0
# Shucked_weight       0
# Viscera_weight       0
# Shell_weight         0
# Rings                0
# dtype: int64

# %% [markdown]
# #### Height(높이)가 0 값이 나오는 것은 이상치로 판단

# %%
# 이상치의 개수가 적은 Glucose, BloodPressure, BMI의 경우 이상치 제거
print("제거 전 데이터 개수: ", len(df))
df = df[(df['Height'] != 0)]
print("제거 후 데이터 개수: ", len(df))
# Out:
# 제거 전 데이터 개수:  4177
# 제거 후 데이터 개수:  4175

# %% [markdown]
# 2개의 데이터 제거

# %%
# Rings 시각화
sns.countplot(data = df, x="Rings")
plt.xlabel("Rings")
plt.ylabel("Count")
plt.title("Abalone")

plt.show()

# %% [markdown]
# ### Rings는 연속적인 수치 데이터를 가지므로 Classification 문제로 다루기 위해선 범주형 값으로 변환하는 과정이 필요

# %%
# 분위수 기반으로 구간 나누기
Rings_binned, bins = pd.qcut(df['Rings'], q=3, labels=['Young', 'Middle-aged', 'Old'], retbins=True)

# 구간 경계값 출력
print("구간 경계값: ", bins)

# 새로운 범주형 피처 생성
df['Rings_binned'] = Rings_binned

# 결과 확인
print(df[['Rings', 'Rings_binned']].head())
# Out:
# 구간 경계값:  [ 1.  8. 11. 29.]
#    Rings Rings_binned
# 0     15          Old
# 1      7        Young
# 2      9  Middle-aged
# 3     10  Middle-aged
# 4      7        Young

# %% [markdown]
# ### pd.qcut 함수를 통해 각 구간에 비슷한 개수의 샘플이 있도록 분위수를 기준으로 구간을 나눔
# - 구간 경계 값을 출력한 결과 (1 ~ 7, 8 ~ 10, 11 ~ 29)의 세 구간('Young', 'Middle-aged', 'Old')으로 나눠진 것을 확인할 수 있음

# %%
df['Rings_binned'].value_counts()
# Out:
# Rings_binned
# Middle-aged    1810
# Young          1405
# Old             960
# Name: count, dtype: int64

# %% [markdown]
# ### 분위 수를 기반으로 나눴지만 Middle-aged와 Old 간의 차이가 두 배정도 나는 것을 확인할 수 있음
# - 추후 OverSampling, UnderSampling 등을 적용할 수 있음

# %%
df = df.drop('Rings', axis=1)
df
# Out:
#       Sex_encoded  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0               2   0.455     0.365   0.095        0.5140          0.2245
# 1               2   0.350     0.265   0.090        0.2255          0.0995
# 2               0   0.530     0.420   0.135        0.6770          0.2565
# 3               2   0.440     0.365   0.125        0.5160          0.2155
# 4               1   0.330     0.255   0.080        0.2050          0.0895
# ...           ...     ...       ...     ...           ...             ...
# 4172            0   0.565     0.450   0.165        0.8870          0.3700
# 4173            2   0.590     0.440   0.135        0.9660          0.4390
# 4174            2   0.600     0.475   0.205        1.1760          0.5255
# 4175            0   0.625     0.485   0.150        1.0945          0.5310
# 4176            2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight Rings_binned
# 0             0.1010        0.1500          Old
# 1             0.0485        0.0700        Young
# 2             0.1415        0.2100  Middle-aged
# 3             0.1140        0.1550  Middle-aged
# 4             0.0395        0.0550        Young
# ...              ...           ...          ...
# 4172          0.2390        0.2490  Middle-aged
# 4173          0.2145        0.2605  Middle-aged
# 4174          0.2875        0.3080  Middle-aged
# 4175          0.2610        0.2960  Middle-aged
# 4176          0.3765        0.4950          Old
#
# [4175 rows x 9 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

# split_sequence 함수
def split_sequence(sequence, labels, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence)-1:
            break
        seq_x, seq_y = sequence[i:end_ix], labels[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    
    return np.array(X), np.array(y)

# %%
# 실제 데이터 적용
sequence = df.drop('Rings_binned', axis=1).values  # 수치형 데이터
labels = df['Rings_binned'].values  # 범주형 레이블 'Rings_binned'

# 시퀀스 분리
n_steps = 7
X, y = split_sequence(sequence, labels, n_steps)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=32)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train, random_state=32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((2667, 7, 8), (834, 7, 8), (2667,), (834,), (667, 7, 8), (667,))

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)
y_test_encoded = label_encoder.transform(y_test)

# %%
from tensorflow.keras.utils import to_categorical

trainy_one_hot = to_categorical(y_train_encoded)
val_one_hot = to_categorical(y_val_encoded)
testy_one_hot = to_categorical(y_test_encoded)

# %% [markdown]
# ## DL Model (CNN)

# %%
n_timesteps, n_features = X_train.shape[1], X_train.shape[2]

# %%
# Model 3
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=2, activation='relu', input_shape=(n_timesteps, n_features)))
model.add((Dropout(0.5)))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add((Dropout(0.5)))
model.add(Conv1D(filters=32, kernel_size=4, activation='relu', padding='same'))
model.add((Dropout(0.5)))
model.add(Flatten())
model.add(Dense(16, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 6, 32)             544
#
#  dropout (Dropout)           (None, 6, 32)             0
#
#  conv1d_1 (Conv1D)           (None, 6, 64)             6208
#
#  dropout_1 (Dropout)         (None, 6, 64)             0
#
#  conv1d_2 (Conv1D)           (None, 6, 32)             8224
#
#  dropout_2 (Dropout)         (None, 6, 32)             0
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 16)                3088
#
#  dense_1 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 18,115
# Trainable params: 18,115
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

train_epochs = 50
history = model.fit(X_train, trainy_one_hot, epochs=train_epochs, batch_size=batch_size, validation_data=(X_val, val_one_hot), verbose=True, shuffle=True)
# Out:
# Epoch 1/50
# 167/167 [==============================] - 10s 11ms/step - loss: 1.0701 - accuracy: 0.4447 - val_loss: 1.0374 - val_accuracy: 0.5487
# Epoch 2/50
# 167/167 [==============================] - 1s 6ms/step - loss: 1.0278 - accuracy: 0.5178 - val_loss: 0.9952 - val_accuracy: 0.5502
# Epoch 3/50
# 167/167 [==============================] - 1s 7ms/step - loss: 0.9809 - accuracy: 0.5549 - val_loss: 0.9445 - val_accuracy: 0.5502
# Epoch 4/50
# 167/167 [==============================] - 1s 7ms/step - loss: 0.9539 - accuracy: 0.5594 - val_loss: 0.9330 - val_accuracy: 0.5562
# Epoch 5/50
# 167/167 [==============================] - 1s 6ms/step - loss: 0.9427 - accuracy: 0.5621 - val_loss: 0.9182 - val_accuracy: 0.5622
# Epoch 6/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.9345 - accuracy: 0.5572 - val_loss: 0.9085 - val_accuracy: 0.5697
# Epoch 7/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.9186 - accuracy: 0.5681 - val_loss: 0.9078 - val_accuracy: 0.5787
# Epoch 8/50
# 167/167 [==============================] - 1s 6ms/step - loss: 0.9153 - accuracy: 0.5602 - val_loss: 0.8977 - val_accuracy: 0.5817
# Epoch 9/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.9100 - accuracy: 0.5767 - val_loss: 0.8776 - val_accuracy: 0.5682
# Epoch 10/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8912 - accuracy: 0.5834 - val_loss: 0.8861 - val_accuracy: 0.6087
# Epoch 11/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8796 - accuracy: 0.5827 - val_loss: 0.8588 - val_accuracy: 0.5967
# Epoch 12/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8691 - accuracy: 0.5943 - val_loss: 0.8413 - val_accuracy: 0.6012
# Epoch 13/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8633 - accuracy: 0.5973 - val_loss: 0.8379 - val_accuracy: 0.6087
# Epoch 14/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8524 - accuracy: 0.5999 - val_loss: 0.8209 - val_accuracy: 0.6207
# Epoch 15/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8492 - accuracy: 0.6085 - val_loss: 0.8257 - val_accuracy: 0.6207
# Epoch 16/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8398 - accuracy: 0.6157 - val_loss: 0.8197 - val_accuracy: 0.6252
# Epoch 17/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8441 - accuracy: 0.6123 - val_loss: 0.8149 - val_accuracy: 0.6102
# Epoch 18/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8376 - accuracy: 0.6157 - val_loss: 0.8133 - val_accuracy: 0.6387
# Epoch 19/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8309 - accuracy: 0.6310 - val_loss: 0.8100 - val_accuracy: 0.6327
# Epoch 20/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8264 - accuracy: 0.6239 - val_loss: 0.7988 - val_accuracy: 0.6417
# Epoch 21/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8285 - accuracy: 0.6142 - val_loss: 0.8076 - val_accuracy: 0.6297
# Epoch 22/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8204 - accuracy: 0.6378 - val_loss: 0.8041 - val_accuracy: 0.6492
# Epoch 23/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8206 - accuracy: 0.6344 - val_loss: 0.8092 - val_accuracy: 0.6327
# Epoch 24/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8161 - accuracy: 0.6325 - val_loss: 0.8014 - val_accuracy: 0.6387
# Epoch 25/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8104 - accuracy: 0.6325 - val_loss: 0.8213 - val_accuracy: 0.6327
# Epoch 26/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8105 - accuracy: 0.6314 - val_loss: 0.8049 - val_accuracy: 0.6372
# Epoch 27/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8096 - accuracy: 0.6277 - val_loss: 0.7984 - val_accuracy: 0.6447
# Epoch 28/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8152 - accuracy: 0.6333 - val_loss: 0.8064 - val_accuracy: 0.6522
# Epoch 29/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8055 - accuracy: 0.6367 - val_loss: 0.8025 - val_accuracy: 0.6417
# Epoch 30/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8027 - accuracy: 0.6374 - val_loss: 0.7910 - val_accuracy: 0.6447
# Epoch 31/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8054 - accuracy: 0.6438 - val_loss: 0.7871 - val_accuracy: 0.6447
# Epoch 32/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8059 - accuracy: 0.6393 - val_loss: 0.7865 - val_accuracy: 0.6507
# Epoch 33/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8017 - accuracy: 0.6494 - val_loss: 0.7831 - val_accuracy: 0.6477
# Epoch 34/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.7928 - accuracy: 0.6397 - val_loss: 0.7921 - val_accuracy: 0.6387
# Epoch 35/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.8041 - accuracy: 0.6412 - val_loss: 0.7933 - val_accuracy: 0.6402
# Epoch 36/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.7867 - accuracy: 0.6453 - val_loss: 0.7885 - val_accuracy: 0.6597
# Epoch 37/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.7885 - accuracy: 0.6363 - val_loss: 0.8151 - val_accuracy: 0.6342
# Epoch 38/50
# 167/167 [==============================] - 1s 4ms/step - loss: 0.7881 - accuracy: 0.6393 - val_loss: 0.7780 - val_accuracy: 0.6432
# Epoch 39/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.7931 - accuracy: 0.6367 - val_loss: 0.7768 - val_accuracy: 0.6432
# Epoch 40/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.7865 - accuracy: 0.6569 - val_loss: 0.7886 - val_accuracy: 0.6267
# Epoch 41/50
# 167/167 [==============================] - 1s 4ms/step - loss: 0.7934 - accuracy: 0.6408 - val_loss: 0.7761 - val_accuracy: 0.6537
# Epoch 42/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.7814 - accuracy: 0.6449 - val_loss: 0.7754 - val_accuracy: 0.6492
# Epoch 43/50
# 167/167 [==============================] - 1s 4ms/step - loss: 0.7871 - accuracy: 0.6370 - val_loss: 0.7780 - val_accuracy: 0.6537
# Epoch 44/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.7870 - accuracy: 0.6419 - val_loss: 0.7672 - val_accuracy: 0.6507
# Epoch 45/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.7930 - accuracy: 0.6513 - val_loss: 0.7847 - val_accuracy: 0.6402
# Epoch 46/50
# 167/167 [==============================] - 1s 5ms/step - loss: 0.7824 - accuracy: 0.6460 - val_loss: 0.7737 - val_accuracy: 0.6522
# Epoch 47/50
# 167/167 [==============================] - 1s 4ms/step - loss: 0.7839 - accuracy: 0.6528 - val_loss: 0.7962 - val_accuracy: 0.6447
# Epoch 48/50
# 167/167 [==============================] - 1s 4ms/step - loss: 0.7764 - accuracy: 0.6520 - val_loss: 0.7704 - val_accuracy: 0.6477
# Epoch 49/50
# 167/167 [==============================] - 1s 4ms/step - loss: 0.7866 - accuracy: 0.6479 - val_loss: 0.7676 - val_accuracy: 0.6567
# Epoch 50/50
# 167/167 [==============================] - 1s 4ms/step - loss: 0.7843 - accuracy: 0.6505 - val_loss: 0.7818 - val_accuracy: 0.6507

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

predy=model.predict(X_test)
predy=np.argmax(predy, axis=-1)
LABELS = ['Young', 'Middle-aged', 'Old']
cm=confusion_matrix(y_test_encoded,predy)
print(cm)
print(accuracy_score(y_test_encoded,predy))
print(f1_score(y_test_encoded,predy, average='weighted'))
print(classification_report(y_test_encoded,predy))
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 27/27 [==============================] - 0s 2ms/step
# [[272  47  43]
#  [ 83  95  14]
#  [ 81  18 181]]
# 0.657074340527578
# 0.6547829516402027
#               precision    recall  f1-score   support
#
#            0       0.62      0.75      0.68       362
#            1       0.59      0.49      0.54       192
#            2       0.76      0.65      0.70       280
#
#     accuracy                           0.66       834
#    macro avg       0.66      0.63      0.64       834
# weighted avg       0.66      0.66      0.65       834
# <Axes: >

# %% [markdown]
# ### 데이터 전처리 단계에서 정확도 올리기
# - Rings와 상관관계가 비교적 낮았던 Sex_encoded, Shucked_weight 제거
# - Smote 함수를 사용한 label OverSampling

# %%
df = df.drop(['Sex_encoded'], axis=1)
df
# Out:
#       Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell_weight Rings_binned
# 0           0.1500          Old
# 1           0.0700        Young
# 2           0.2100  Middle-aged
# 3           0.1550  Middle-aged
# 4           0.0550        Young
# ...            ...          ...
# 4172        0.2490  Middle-aged
# 4173        0.2605  Middle-aged
# 4174        0.3080  Middle-aged
# 4175        0.2960  Middle-aged
# 4176        0.4950          Old
#
# [4175 rows x 8 columns]

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(df.drop('Rings_binned', axis=1), df['Rings_binned'])

# %%
y_resampled.value_counts()
# Out:
# Rings_binned
# Young          1810
# Middle-aged    1810
# Old            1810
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# y_resampled의 클래스 분포를 계산
value_counts = y_resampled.value_counts()

# 시각화
plt.figure(figsize=(8, 6))
value_counts.plot(kind='bar', color=["#1f77b4", "#ff7f0e", "#2ca02c"])  # 막대그래프 생성
plt.title('Class Distribution after Resampling')
plt.xlabel('Class Labels')
plt.ylabel('Frequency')
plt.xticks(rotation=0)  # x축 레이블 수평으로 표시
plt.show()

# %%
# 실제 데이터 적용
sequence = X_resampled.values  # 수치형 데이터
labels = y_resampled.values  # 범주형 레이블 'Rings_binned'

# 시퀀스 분리
n_steps = 7
X, y = split_sequence(sequence, labels, n_steps)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=32)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train, random_state=32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((3470, 7, 7), (1085, 7, 7), (3470,), (1085,), (868, 7, 7), (868,))

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)
y_test_encoded = label_encoder.transform(y_test)

# %%
from tensorflow.keras.utils import to_categorical

trainy_one_hot = to_categorical(y_train_encoded)
val_one_hot = to_categorical(y_val_encoded)
testy_one_hot = to_categorical(y_test_encoded)

# %%
n_timesteps, n_features = X_train.shape[1], X_train.shape[2]

# %%
# Model 3
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=2, activation='relu', input_shape=(n_timesteps, n_features)))
model.add((Dropout(0.5)))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add((Dropout(0.5)))
model.add(Conv1D(filters=32, kernel_size=4, activation='relu', padding='same'))
model.add((Dropout(0.5)))
model.add(Flatten())
model.add(Dense(16, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 6, 32)             480
#
#  dropout_3 (Dropout)         (None, 6, 32)             0
#
#  conv1d_4 (Conv1D)           (None, 6, 64)             6208
#
#  dropout_4 (Dropout)         (None, 6, 64)             0
#
#  conv1d_5 (Conv1D)           (None, 6, 32)             8224
#
#  dropout_5 (Dropout)         (None, 6, 32)             0
#
#  flatten_1 (Flatten)         (None, 192)               0
#
#  dense_2 (Dense)             (None, 16)                3088
#
#  dense_3 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 18,051
# Trainable params: 18,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

train_epochs = 50
history = model.fit(X_train, trainy_one_hot, epochs=train_epochs, batch_size=batch_size, validation_data=(X_val, val_one_hot), verbose=True, shuffle=True)
# Out:
# Epoch 1/50
# 217/217 [==============================] - 2s 6ms/step - loss: 1.0477 - accuracy: 0.4329 - val_loss: 0.9470 - val_accuracy: 0.5518
# Epoch 2/50
# 217/217 [==============================] - 1s 4ms/step - loss: 0.9672 - accuracy: 0.5069 - val_loss: 0.9200 - val_accuracy: 0.5576
# Epoch 3/50
# 217/217 [==============================] - 1s 4ms/step - loss: 0.9268 - accuracy: 0.5360 - val_loss: 0.8725 - val_accuracy: 0.6866
# Epoch 4/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.8828 - accuracy: 0.6069 - val_loss: 0.7936 - val_accuracy: 0.6982
# Epoch 5/50
# 217/217 [==============================] - 1s 4ms/step - loss: 0.8298 - accuracy: 0.6513 - val_loss: 0.7750 - val_accuracy: 0.6671
# Epoch 6/50
# 217/217 [==============================] - 1s 4ms/step - loss: 0.8093 - accuracy: 0.6625 - val_loss: 0.7587 - val_accuracy: 0.6866
# Epoch 7/50
# 217/217 [==============================] - 1s 4ms/step - loss: 0.7990 - accuracy: 0.6732 - val_loss: 0.7236 - val_accuracy: 0.7085
# Epoch 8/50
# 217/217 [==============================] - 1s 4ms/step - loss: 0.7833 - accuracy: 0.6741 - val_loss: 0.7064 - val_accuracy: 0.7258
# Epoch 9/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7676 - accuracy: 0.6853 - val_loss: 0.7102 - val_accuracy: 0.7143
# Epoch 10/50
# 217/217 [==============================] - 1s 4ms/step - loss: 0.7636 - accuracy: 0.6890 - val_loss: 0.7057 - val_accuracy: 0.6993
# Epoch 11/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7591 - accuracy: 0.6850 - val_loss: 0.6897 - val_accuracy: 0.7362
# Epoch 12/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7487 - accuracy: 0.6974 - val_loss: 0.6783 - val_accuracy: 0.7316
# Epoch 13/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7406 - accuracy: 0.6954 - val_loss: 0.6986 - val_accuracy: 0.7074
# Epoch 14/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7393 - accuracy: 0.6925 - val_loss: 0.6983 - val_accuracy: 0.7200
# Epoch 15/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7326 - accuracy: 0.6977 - val_loss: 0.6756 - val_accuracy: 0.7293
# Epoch 16/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7227 - accuracy: 0.7040 - val_loss: 0.6864 - val_accuracy: 0.7327
# Epoch 17/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7317 - accuracy: 0.6974 - val_loss: 0.6693 - val_accuracy: 0.7350
# Epoch 18/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7307 - accuracy: 0.7003 - val_loss: 0.6913 - val_accuracy: 0.7120
# Epoch 19/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7176 - accuracy: 0.7049 - val_loss: 0.6759 - val_accuracy: 0.7316
# Epoch 20/50
# 217/217 [==============================] - 1s 6ms/step - loss: 0.7170 - accuracy: 0.7107 - val_loss: 0.7022 - val_accuracy: 0.7051
# Epoch 21/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7232 - accuracy: 0.7012 - val_loss: 0.6895 - val_accuracy: 0.7039
# Epoch 22/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7083 - accuracy: 0.7058 - val_loss: 0.6703 - val_accuracy: 0.7189
# Epoch 23/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7145 - accuracy: 0.7055 - val_loss: 0.6910 - val_accuracy: 0.7189
# Epoch 24/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7104 - accuracy: 0.7040 - val_loss: 0.6751 - val_accuracy: 0.7235
# Epoch 25/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7156 - accuracy: 0.7055 - val_loss: 0.6594 - val_accuracy: 0.7293
# Epoch 26/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7123 - accuracy: 0.7121 - val_loss: 0.6799 - val_accuracy: 0.7166
# Epoch 27/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6966 - accuracy: 0.7104 - val_loss: 0.6741 - val_accuracy: 0.7327
# Epoch 28/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7128 - accuracy: 0.7006 - val_loss: 0.6795 - val_accuracy: 0.7062
# Epoch 29/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7032 - accuracy: 0.7040 - val_loss: 0.6593 - val_accuracy: 0.7224
# Epoch 30/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7062 - accuracy: 0.6988 - val_loss: 0.6657 - val_accuracy: 0.7108
# Epoch 31/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7055 - accuracy: 0.7098 - val_loss: 0.7011 - val_accuracy: 0.6935
# Epoch 32/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6992 - accuracy: 0.7101 - val_loss: 0.6474 - val_accuracy: 0.7362
# Epoch 33/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6905 - accuracy: 0.7228 - val_loss: 0.6579 - val_accuracy: 0.7258
# Epoch 34/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6969 - accuracy: 0.7081 - val_loss: 0.6736 - val_accuracy: 0.7224
# Epoch 35/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6913 - accuracy: 0.7130 - val_loss: 0.6330 - val_accuracy: 0.7316
# Epoch 36/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6893 - accuracy: 0.7130 - val_loss: 0.6549 - val_accuracy: 0.7154
# Epoch 37/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6901 - accuracy: 0.7147 - val_loss: 0.6807 - val_accuracy: 0.7028
# Epoch 38/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6892 - accuracy: 0.7213 - val_loss: 0.6616 - val_accuracy: 0.7247
# Epoch 39/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.7067 - accuracy: 0.7092 - val_loss: 0.6747 - val_accuracy: 0.7177
# Epoch 40/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6943 - accuracy: 0.7141 - val_loss: 0.6465 - val_accuracy: 0.7270
# Epoch 41/50
# 217/217 [==============================] - 1s 6ms/step - loss: 0.6892 - accuracy: 0.7161 - val_loss: 0.6512 - val_accuracy: 0.7304
# Epoch 42/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6866 - accuracy: 0.7213 - val_loss: 0.6573 - val_accuracy: 0.7108
# Epoch 43/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6923 - accuracy: 0.7167 - val_loss: 0.6504 - val_accuracy: 0.7247
# Epoch 44/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6919 - accuracy: 0.7121 - val_loss: 0.6546 - val_accuracy: 0.7258
# Epoch 45/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6886 - accuracy: 0.7153 - val_loss: 0.6629 - val_accuracy: 0.7189
# Epoch 46/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6940 - accuracy: 0.7147 - val_loss: 0.6359 - val_accuracy: 0.7258
# Epoch 47/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6908 - accuracy: 0.7164 - val_loss: 0.6435 - val_accuracy: 0.7385
# Epoch 48/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6871 - accuracy: 0.7173 - val_loss: 0.6408 - val_accuracy: 0.7304
# Epoch 49/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6858 - accuracy: 0.7115 - val_loss: 0.6315 - val_accuracy: 0.7362
# Epoch 50/50
# 217/217 [==============================] - 1s 5ms/step - loss: 0.6848 - accuracy: 0.7084 - val_loss: 0.6704 - val_accuracy: 0.7131

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

predy=model.predict(X_test)
predy=np.argmax(predy, axis=-1)
LABELS = ['Young', 'Middle-aged', 'Old']
cm=confusion_matrix(y_test_encoded,predy)
print(cm)
print(accuracy_score(y_test_encoded,predy))
print(f1_score(y_test_encoded,predy, average='weighted'))
print(classification_report(y_test_encoded,predy))
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 34/34 [==============================] - 0s 2ms/step
# [[257  58  47]
#  [ 78 261  23]
#  [ 89  25 247]]
# 0.7050691244239631
# 0.7072918201187784
#               precision    recall  f1-score   support
#
#            0       0.61      0.71      0.65       362
#            1       0.76      0.72      0.74       362
#            2       0.78      0.68      0.73       361
#
#     accuracy                           0.71      1085
#    macro avg       0.71      0.71      0.71      1085
# weighted avg       0.71      0.71      0.71      1085
# <Axes: >
