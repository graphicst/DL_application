# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional, ConvLSTM1D

# %%
df = pd.read_csv("C:/AI_study/abalone.csv")
df
# Out:
#         id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0        0   M   0.455     0.365   0.095        0.5140          0.2245
# 1        1   M   0.350     0.265   0.090        0.2255          0.0995
# 2        2   F   0.530     0.420   0.135        0.6770          0.2565
# 3        3   M   0.440     0.365   0.125        0.5160          0.2155
# 4        4   I   0.330     0.255   0.080        0.2050          0.0895
# ...    ...  ..     ...       ...     ...           ...             ...
# 4172  4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173  4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174  4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175  4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176  4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 10 columns]

# %%
# 데이터 정보 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              4177 non-null   int64
#  1   Sex             4177 non-null   object
#  2   Length          4177 non-null   float64
#  3   Diameter        4177 non-null   float64
#  4   Height          4177 non-null   float64
#  5   Whole_weight    4177 non-null   float64
#  6   Shucked_weight  4177 non-null   float64
#  7   Viscera_weight  4177 non-null   float64
#  8   Shell_weight    4177 non-null   float64
#  9   Rings           4177 non-null   int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 326.5+ KB

# %%
df['Sex'].value_counts()
# Out:
# Sex
# M    1528
# I    1342
# F    1307
# Name: count, dtype: int64

# %% [markdown]
# ## Features
# - id: id
# - Sex: 성별 M(수컷), F(암컷), I(유아기)
# - Length: 길이(앞에서 뒤까지, mm)
# - Diameter: 지름(길이에 수직인 방향, mm)
# - Height: 높이(껍질 포함, mm)
# - Whole_weight: 전체 무게(껍질 포함, g)
# - Shucked_weight: 무게(껍질 제거, g)
# - Viscera_weight: 전복 내장 무게(g)
# - Shell_weight: 건조 후 껍질 무게(g)
# - Rings: 나선(전복의 나이 추정, 나이 = Rings + 1.5) - label

# %% [markdown]
# - 현재 Features 중 id의 경우는 단순히 0 ~ 4176까지 나열한 것이므로 필요 없음
# - Sex의 경우 object형으로 M, F, I를 값으로 가지기 때문에 EDA하고 모델에 넣기 위해 Label Encoding이 필요

# %%
# 필요 없는 Feature인 id 제거
df = df.drop('id', axis=1)
df
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
# Sex 분포 시각화
sns.countplot(data=df, x="Sex", hue="Sex", palette=["#1f77b4", "#ff7f0e", "#2ca02c"])
plt.xlabel("Sex")
plt.ylabel("Count")
plt.title("Sex Distribution")

plt.show()

# %%
# Sex 피처에 Label Encoding 적용

from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
le = LabelEncoder()

df['Sex_encoded'] = le.fit_transform(df['Sex'])

df = df.drop('Sex', axis=1)
df.insert(0, 'Sex_encoded', df.pop('Sex_encoded'))

# 결과 확인
print(df)
# Out:
#       Sex_encoded  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0               2   0.455     0.365   0.095        0.5140          0.2245
# 1               2   0.350     0.265   0.090        0.2255          0.0995
# 2               0   0.530     0.420   0.135        0.6770          0.2565
# 3               2   0.440     0.365   0.125        0.5160          0.2155
# 4               1   0.330     0.255   0.080        0.2050          0.0895
# ...           ...     ...       ...     ...           ...             ...
# 4172            0   0.565     0.450   0.165        0.8870          0.3700
# 4173            2   0.590     0.440   0.135        0.9660          0.4390
# 4174            2   0.600     0.475   0.205        1.1760          0.5255
# 4175            0   0.625     0.485   0.150        1.0945          0.5310
# 4176            2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.describe()
# Out:
#        Sex_encoded       Length     Diameter       Height  Whole_weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked_weight  Viscera_weight  Shell_weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# min          0.001000        0.000500      0.001500     1.000000
# 25%          0.186000        0.093500      0.130000     8.000000
# 50%          0.336000        0.171000      0.234000     9.000000
# 75%          0.502000        0.253000      0.329000    11.000000
# max          1.488000        0.760000      1.005000    29.000000

# %%
# 데이터 결측치 확인
df.isnull().sum()
# Out:
# Sex_encoded       0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
df['Rings'].value_counts()
# Out:
# Rings
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 1       1
# 26      1
# 29      1
# 2       1
# 25      1
# Name: count, dtype: int64

# %%
#상관관계 히트맵 생성
#상관 관계 행렬
df_corr=df.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %% [markdown]
# ## Target인 Rings와 가장 높은 상관 관계를 맺는 feature
# - Shell_weight(0.63)

# %% [markdown]
# ## Target인 Rings와 비교적 낮은 상관 관계를 맺는 features
# - Sex_encoded(-0.035)
# - Shucked_weight(0.42)
# - Visvera_weight(0.5)

# %% [markdown]
# - Sex_encoded의 경우 매우 낮은 상관 관계를 갖고 있기 때문에 추후에 삭제 가능

# %%
df.hist(bins=50, figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'Sex_encoded'}>,
#         <Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Diameter'}>],
#        [<Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Whole_weight'}>,
#         <Axes: title={'center': 'Shucked_weight'}>],
#        [<Axes: title={'center': 'Viscera_weight'}>,
#         <Axes: title={'center': 'Shell_weight'}>,
#         <Axes: title={'center': 'Rings'}>]], dtype=object)

# %%
# Rings와 Shell_weight 관계
plt.scatter(df['Rings'], df['Shell_weight'])
plt.xlabel('Rings')
plt.ylabel('Shell_weight')

plt.show()

# %%
# 각 열에서 0인 값의 개수를 확인
zero_values_count = (df == 0).sum()

# 결과 출력
print(zero_values_count)
# Out:
# Sex_encoded       1307
# Length               0
# Diameter             0
# Height               2
# Whole_weight         0
# Shucked_weight       0
# Viscera_weight       0
# Shell_weight         0
# Rings                0
# dtype: int64

# %% [markdown]
# #### Height(높이)가 0 값이 나오는 것은 이상치로 판단

# %%
# 이상치의 개수가 적은 Glucose, BloodPressure, BMI의 경우 이상치 제거
print("제거 전 데이터 개수: ", len(df))
df = df[(df['Height'] != 0)]
print("제거 후 데이터 개수: ", len(df))
# Out:
# 제거 전 데이터 개수:  4177
# 제거 후 데이터 개수:  4175

# %% [markdown]
# 2개의 데이터 제거

# %%
# Rings 시각화
sns.countplot(data = df, x="Rings")
plt.xlabel("Rings")
plt.ylabel("Count")
plt.title("Abalone")

plt.show()

# %%
# split_sequence 함수
def split_sequence(df, n_steps):
    X, y = [], []
    for i in range(len(df) - n_steps):
        seq_x = df.iloc[i:i+n_steps, :-1].values  # 마지막 열(Rings)을 제외한 특징들
        seq_y = df.iloc[i+n_steps, -1]  # Rings (예측할 값)
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
n_steps = 7

X, y = split_sequence(df, n_steps)
print("입력 데이터 (X):", X)
print("출력 데이터 (y):", y)
# Out:
# 입력 데이터 (X): [[[2.     0.455  0.365  ... 0.2245 0.101  0.15  ]
#   [2.     0.35   0.265  ... 0.0995 0.0485 0.07  ]
#   [0.     0.53   0.42   ... 0.2565 0.1415 0.21  ]
#   ...
#   [1.     0.33   0.255  ... 0.0895 0.0395 0.055 ]
#   [1.     0.425  0.3    ... 0.141  0.0775 0.12  ]
#   [0.     0.53   0.415  ... 0.237  0.1415 0.33  ]]
#
#  [[2.     0.35   0.265  ... 0.0995 0.0485 0.07  ]
#   [0.     0.53   0.42   ... 0.2565 0.1415 0.21  ]
#   [2.     0.44   0.365  ... 0.2155 0.114  0.155 ]
#   ...
#   [1.     0.425  0.3    ... 0.141  0.0775 0.12  ]
#   [0.     0.53   0.415  ... 0.237  0.1415 0.33  ]
#   [0.     0.545  0.425  ... 0.294  0.1495 0.26  ]]
#
#  [[0.     0.53   0.42   ... 0.2565 0.1415 0.21  ]
#   [2.     0.44   0.365  ... 0.2155 0.114  0.155 ]
#   [1.     0.33   0.255  ... 0.0895 0.0395 0.055 ]
#   ...
#   [0.     0.53   0.415  ... 0.237  0.1415 0.33  ]
#   [0.     0.545  0.425  ... 0.294  0.1495 0.26  ]
#   [2.     0.475  0.37   ... 0.2165 0.1125 0.165 ]]
#
#  ...
#
#  [[2.     0.5    0.38   ... 0.269  0.1265 0.1535]
#   [0.     0.515  0.4    ... 0.2865 0.123  0.1765]
#   [2.     0.52   0.385  ... 0.375  0.18   0.1815]
#   ...
#   [2.     0.56   0.43   ... 0.4    0.172  0.229 ]
#   [0.     0.565  0.45   ... 0.37   0.239  0.249 ]
#   [2.     0.59   0.44   ... 0.439  0.2145 0.2605]]
#
#  [[0.     0.515  0.4    ... 0.2865 0.123  0.1765]
#   [2.     0.52   0.385  ... 0.375  0.18   0.1815]
#   [2.     0.55   0.43   ... 0.3155 0.1955 0.2405]
#   ...
#   [0.     0.565  0.45   ... 0.37   0.239  0.249 ]
#   [2.     0.59   0.44   ... 0.439  0.2145 0.2605]
#   [2.     0.6    0.475  ... 0.5255 0.2875 0.308 ]]
#
#  [[2.     0.52   0.385  ... 0.375  0.18   0.1815]
#   [2.     0.55   0.43   ... 0.3155 0.1955 0.2405]
#   [2.     0.56   0.43   ... 0.4    0.172  0.229 ]
#   ...
#   [2.     0.59   0.44   ... 0.439  0.2145 0.2605]
#   [2.     0.6    0.475  ... 0.5255 0.2875 0.308 ]
#   [0.     0.625  0.485  ... 0.531  0.261  0.296 ]]]
# 출력 데이터 (y): [16  9 19 ...  9 10 12]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=32)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((2667, 7, 8), (834, 7, 8), (2667,), (834,), (667, 7, 8), (667,))

# %% [markdown]
# ## DL Model (LSTM)

# %%
n_timesteps, n_features = X_train.shape[1], X_train.shape[2]

# %%
from tensorflow.keras.layers import LSTM, Conv1D, GRU
model = Sequential()
model.add(LSTM(16, return_sequences = True, input_shape=(n_timesteps, n_features)))
model.add(LSTM(32, return_sequences = True))
model.add(LSTM(48))      
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='linear'))  # 출력 레이어, 회귀이므로 'linear' 사용
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])  # 회귀에서는 MSE 사용
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 7, 16)             1600
#
#  lstm_1 (LSTM)               (None, 7, 32)             6272
#
#  lstm_2 (LSTM)               (None, 48)                15552
#
#  dense (Dense)               (None, 8)                 392
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 23,825
# Trainable params: 23,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

train_epochs = 50
history = model.fit(X_train, y_train, epochs=train_epochs, batch_size=batch_size, validation_data=(X_val, y_val), verbose=True, shuffle=True)
# Out:
# Epoch 1/50
# 167/167 [==============================] - 8s 13ms/step - loss: 25.2524 - mean_squared_error: 25.2524 - val_loss: 9.7320 - val_mean_squared_error: 9.7320
# Epoch 2/50
# 167/167 [==============================] - 1s 9ms/step - loss: 10.5041 - mean_squared_error: 10.5041 - val_loss: 9.7288 - val_mean_squared_error: 9.7288
# Epoch 3/50
# 167/167 [==============================] - 1s 8ms/step - loss: 10.4263 - mean_squared_error: 10.4263 - val_loss: 9.5363 - val_mean_squared_error: 9.5363
# Epoch 4/50
# 167/167 [==============================] - 1s 8ms/step - loss: 10.1564 - mean_squared_error: 10.1564 - val_loss: 9.2825 - val_mean_squared_error: 9.2825
# Epoch 5/50
# 167/167 [==============================] - 1s 8ms/step - loss: 9.9728 - mean_squared_error: 9.9728 - val_loss: 9.1407 - val_mean_squared_error: 9.1407
# Epoch 6/50
# 167/167 [==============================] - 1s 8ms/step - loss: 9.8617 - mean_squared_error: 9.8617 - val_loss: 9.0178 - val_mean_squared_error: 9.0178
# Epoch 7/50
# 167/167 [==============================] - 1s 8ms/step - loss: 9.7545 - mean_squared_error: 9.7545 - val_loss: 8.8436 - val_mean_squared_error: 8.8436
# Epoch 8/50
# 167/167 [==============================] - 1s 8ms/step - loss: 9.4666 - mean_squared_error: 9.4666 - val_loss: 8.5499 - val_mean_squared_error: 8.5499
# Epoch 9/50
# 167/167 [==============================] - 1s 8ms/step - loss: 9.0578 - mean_squared_error: 9.0578 - val_loss: 8.6045 - val_mean_squared_error: 8.6045
# Epoch 10/50
# 167/167 [==============================] - 1s 7ms/step - loss: 8.5513 - mean_squared_error: 8.5513 - val_loss: 7.6635 - val_mean_squared_error: 7.6635
# Epoch 11/50
# 167/167 [==============================] - 1s 8ms/step - loss: 8.0173 - mean_squared_error: 8.0173 - val_loss: 7.1266 - val_mean_squared_error: 7.1266
# Epoch 12/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.6815 - mean_squared_error: 7.6815 - val_loss: 7.0062 - val_mean_squared_error: 7.0062
# Epoch 13/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.5325 - mean_squared_error: 7.5325 - val_loss: 6.8955 - val_mean_squared_error: 6.8955
# Epoch 14/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.5399 - mean_squared_error: 7.5399 - val_loss: 6.8881 - val_mean_squared_error: 6.8881
# Epoch 15/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.4637 - mean_squared_error: 7.4637 - val_loss: 6.7026 - val_mean_squared_error: 6.7026
# Epoch 16/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.5579 - mean_squared_error: 7.5579 - val_loss: 6.6605 - val_mean_squared_error: 6.6605
# Epoch 17/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.3438 - mean_squared_error: 7.3438 - val_loss: 7.6136 - val_mean_squared_error: 7.6136
# Epoch 18/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.3608 - mean_squared_error: 7.3608 - val_loss: 6.9498 - val_mean_squared_error: 6.9498
# Epoch 19/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.3769 - mean_squared_error: 7.3769 - val_loss: 7.1713 - val_mean_squared_error: 7.1713
# Epoch 20/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.3513 - mean_squared_error: 7.3513 - val_loss: 6.6219 - val_mean_squared_error: 6.6219
# Epoch 21/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.2549 - mean_squared_error: 7.2549 - val_loss: 6.6539 - val_mean_squared_error: 6.6539
# Epoch 22/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.2525 - mean_squared_error: 7.2525 - val_loss: 6.6152 - val_mean_squared_error: 6.6152
# Epoch 23/50
# 167/167 [==============================] - 1s 7ms/step - loss: 7.2428 - mean_squared_error: 7.2428 - val_loss: 6.5668 - val_mean_squared_error: 6.5668
# Epoch 24/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.3814 - mean_squared_error: 7.3814 - val_loss: 6.5911 - val_mean_squared_error: 6.5911
# Epoch 25/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.2208 - mean_squared_error: 7.2208 - val_loss: 6.6984 - val_mean_squared_error: 6.6984
# Epoch 26/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.1665 - mean_squared_error: 7.1665 - val_loss: 6.8130 - val_mean_squared_error: 6.8130
# Epoch 27/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.1849 - mean_squared_error: 7.1849 - val_loss: 6.6101 - val_mean_squared_error: 6.6101
# Epoch 28/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.0747 - mean_squared_error: 7.0747 - val_loss: 6.6852 - val_mean_squared_error: 6.6852
# Epoch 29/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.1381 - mean_squared_error: 7.1381 - val_loss: 6.5278 - val_mean_squared_error: 6.5278
# Epoch 30/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.1301 - mean_squared_error: 7.1301 - val_loss: 6.7321 - val_mean_squared_error: 6.7321
# Epoch 31/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.0601 - mean_squared_error: 7.0601 - val_loss: 6.5250 - val_mean_squared_error: 6.5250
# Epoch 32/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.2719 - mean_squared_error: 7.2719 - val_loss: 6.6959 - val_mean_squared_error: 6.6959
# Epoch 33/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.1668 - mean_squared_error: 7.1668 - val_loss: 6.5555 - val_mean_squared_error: 6.5555
# Epoch 34/50
# 167/167 [==============================] - 1s 8ms/step - loss: 6.9939 - mean_squared_error: 6.9939 - val_loss: 6.5264 - val_mean_squared_error: 6.5264
# Epoch 35/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.0852 - mean_squared_error: 7.0852 - val_loss: 6.5345 - val_mean_squared_error: 6.5345
# Epoch 36/50
# 167/167 [==============================] - 1s 8ms/step - loss: 6.9693 - mean_squared_error: 6.9693 - val_loss: 6.6715 - val_mean_squared_error: 6.6715
# Epoch 37/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.0424 - mean_squared_error: 7.0424 - val_loss: 7.0787 - val_mean_squared_error: 7.0787
# Epoch 38/50
# 167/167 [==============================] - 1s 8ms/step - loss: 6.9845 - mean_squared_error: 6.9845 - val_loss: 6.4789 - val_mean_squared_error: 6.4789
# Epoch 39/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.0506 - mean_squared_error: 7.0506 - val_loss: 6.7161 - val_mean_squared_error: 6.7161
# Epoch 40/50
# 167/167 [==============================] - 1s 8ms/step - loss: 7.0768 - mean_squared_error: 7.0768 - val_loss: 7.0779 - val_mean_squared_error: 7.0779
# Epoch 41/50
# 167/167 [==============================] - 1s 7ms/step - loss: 7.1056 - mean_squared_error: 7.1056 - val_loss: 6.8478 - val_mean_squared_error: 6.8478
# Epoch 42/50
# 167/167 [==============================] - 1s 8ms/step - loss: 6.9256 - mean_squared_error: 6.9256 - val_loss: 6.5006 - val_mean_squared_error: 6.5006
# Epoch 43/50
# 167/167 [==============================] - 1s 8ms/step - loss: 6.9201 - mean_squared_error: 6.9201 - val_loss: 6.5629 - val_mean_squared_error: 6.5629
# Epoch 44/50
# 167/167 [==============================] - 1s 8ms/step - loss: 6.9418 - mean_squared_error: 6.9418 - val_loss: 6.6986 - val_mean_squared_error: 6.6986
# Epoch 45/50
# 167/167 [==============================] - 1s 8ms/step - loss: 6.9848 - mean_squared_error: 6.9848 - val_loss: 6.7202 - val_mean_squared_error: 6.7202
# Epoch 46/50
# 167/167 [==============================] - 1s 8ms/step - loss: 6.8644 - mean_squared_error: 6.8644 - val_loss: 6.4988 - val_mean_squared_error: 6.4988
# Epoch 47/50
# 167/167 [==============================] - 1s 8ms/step - loss: 6.8464 - mean_squared_error: 6.8464 - val_loss: 6.9235 - val_mean_squared_error: 6.9235
# Epoch 48/50
# 167/167 [==============================] - 1s 7ms/step - loss: 6.8439 - mean_squared_error: 6.8439 - val_loss: 6.9624 - val_mean_squared_error: 6.9624
# Epoch 49/50
# 167/167 [==============================] - 1s 8ms/step - loss: 6.7927 - mean_squared_error: 6.7927 - val_loss: 6.8772 - val_mean_squared_error: 6.8772
# Epoch 50/50
# 167/167 [==============================] - 1s 8ms/step - loss: 6.7903 - mean_squared_error: 6.7903 - val_loss: 6.6239 - val_mean_squared_error: 6.6239

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model MSE Loss')  # 'model loss'를 'Model MSE Loss'로 변경
plt.ylabel('MSE Loss')  # y축 레이블을 'MSE Loss'로 변경
plt.xlabel('Epoch')  # x축 레이블은 'Epoch' 그대로 유지
plt.legend(['Train', 'Validation'], loc='upper left')  # 범례 그대로 유지
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# 모델이 예측한 연속적인 값 (회귀)
predy = model.predict(X_test)

# 성능 지표 계산 (MSE, MAE, R^2)
mse = mean_squared_error(y_test, predy)
mae = mean_absolute_error(y_test, predy)
r2 = r2_score(y_test, predy)

print(f'MSE: {mse}')
print(f'MAE: {mae}')
print(f'R^2 Score: {r2}')

# 예측값 vs 실제값 시각화
plt.scatter(y_test, predy, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.title('Actual vs Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# 27/27 [==============================] - 1s 6ms/step
# MSE: 6.545359470162997
# MAE: 1.7939515222462532
# R^2 Score: 0.3848187727723785
# Text(0, 0.5, 'Predicted Values')
