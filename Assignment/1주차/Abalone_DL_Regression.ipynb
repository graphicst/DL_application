# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score, classification_report

# %%
df = pd.read_csv("C:/AI_study/abalone.csv")
df
# Out:
#         id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0        0   M   0.455     0.365   0.095        0.5140          0.2245
# 1        1   M   0.350     0.265   0.090        0.2255          0.0995
# 2        2   F   0.530     0.420   0.135        0.6770          0.2565
# 3        3   M   0.440     0.365   0.125        0.5160          0.2155
# 4        4   I   0.330     0.255   0.080        0.2050          0.0895
# ...    ...  ..     ...       ...     ...           ...             ...
# 4172  4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173  4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174  4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175  4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176  4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 10 columns]

# %%
# 데이터 정보 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              4177 non-null   int64
#  1   Sex             4177 non-null   object
#  2   Length          4177 non-null   float64
#  3   Diameter        4177 non-null   float64
#  4   Height          4177 non-null   float64
#  5   Whole_weight    4177 non-null   float64
#  6   Shucked_weight  4177 non-null   float64
#  7   Viscera_weight  4177 non-null   float64
#  8   Shell_weight    4177 non-null   float64
#  9   Rings           4177 non-null   int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 326.5+ KB

# %%
df['Sex'].value_counts()
# Out:
# Sex
# M    1528
# I    1342
# F    1307
# Name: count, dtype: int64

# %% [markdown]
# ## Features
# - id: id
# - Sex: 성별 M(수컷), F(암컷), I(유아기)
# - Length: 길이(앞에서 뒤까지, mm)
# - Diameter: 지름(길이에 수직인 방향, mm)
# - Height: 높이(껍질 포함, mm)
# - Whole_weight: 전체 무게(껍질 포함, g)
# - Shucked_weight: 무게(껍질 제거, g)
# - Viscera_weight: 전복 내장 무게(g)
# - Shell_weight: 건조 후 껍질 무게(g)
# - Rings: 나선(전복의 나이 추정, 나이 = Rings + 1.5) - label

# %% [markdown]
# - 현재 Features 중 id의 경우는 단순히 0 ~ 4176까지 나열한 것이므로 필요 없음
# - Sex의 경우 object형으로 M, F, I를 값으로 가지기 때문에 EDA하고 모델에 넣기 위해 Label Encoding이 필요

# %%
# 필요 없는 Feature인 id 제거
df = df.drop('id', axis=1)
df
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
# Sex 분포 시각화
sns.countplot(data=df, x="Sex", hue="Sex", palette=["#1f77b4", "#ff7f0e", "#2ca02c"])
plt.xlabel("Sex")
plt.ylabel("Count")
plt.title("Sex Distribution")

plt.show()

# %%
# Sex 피처에 Label Encoding 적용

from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
le = LabelEncoder()

df['Sex_encoded'] = le.fit_transform(df['Sex'])

df = df.drop('Sex', axis=1)
df.insert(0, 'Sex_encoded', df.pop('Sex_encoded'))

# 결과 확인
print(df)
# Out:
#       Sex_encoded  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0               2   0.455     0.365   0.095        0.5140          0.2245
# 1               2   0.350     0.265   0.090        0.2255          0.0995
# 2               0   0.530     0.420   0.135        0.6770          0.2565
# 3               2   0.440     0.365   0.125        0.5160          0.2155
# 4               1   0.330     0.255   0.080        0.2050          0.0895
# ...           ...     ...       ...     ...           ...             ...
# 4172            0   0.565     0.450   0.165        0.8870          0.3700
# 4173            2   0.590     0.440   0.135        0.9660          0.4390
# 4174            2   0.600     0.475   0.205        1.1760          0.5255
# 4175            0   0.625     0.485   0.150        1.0945          0.5310
# 4176            2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.describe()
# Out:
#        Sex_encoded       Length     Diameter       Height  Whole_weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked_weight  Viscera_weight  Shell_weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# min          0.001000        0.000500      0.001500     1.000000
# 25%          0.186000        0.093500      0.130000     8.000000
# 50%          0.336000        0.171000      0.234000     9.000000
# 75%          0.502000        0.253000      0.329000    11.000000
# max          1.488000        0.760000      1.005000    29.000000

# %%
# 데이터 결측치 확인
df.isnull().sum()
# Out:
# Sex_encoded       0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
df['Rings'].value_counts()
# Out:
# Rings
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 1       1
# 26      1
# 29      1
# 2       1
# 25      1
# Name: count, dtype: int64

# %%
#상관관계 히트맵 생성
#상관 관계 행렬
df_corr=df.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %% [markdown]
# ## Target인 Rings와 가장 높은 상관 관계를 맺는 feature
# - Shell_weight(0.63)

# %% [markdown]
# ## Target인 Rings와 비교적 낮은 상관 관계를 맺는 features
# - Sex_encoded(-0.035)
# - Shucked_weight(0.42)
# - Visvera_weight(0.5)

# %% [markdown]
# - Sex_encoded의 경우 매우 낮은 상관 관계를 갖고 있기 때문에 추후에 삭제 가능

# %%
df.hist(bins=50, figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'Sex_encoded'}>,
#         <Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Diameter'}>],
#        [<Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Whole_weight'}>,
#         <Axes: title={'center': 'Shucked_weight'}>],
#        [<Axes: title={'center': 'Viscera_weight'}>,
#         <Axes: title={'center': 'Shell_weight'}>,
#         <Axes: title={'center': 'Rings'}>]], dtype=object)

# %%
# Rings와 Shell_weight 관계
plt.scatter(df['Rings'], df['Shell_weight'])
plt.xlabel('Rings')
plt.ylabel('Shell_weight')

plt.show()

# %%
# 각 열에서 0인 값의 개수를 확인
zero_values_count = (df == 0).sum()

# 결과 출력
print(zero_values_count)
# Out:
# Sex_encoded       1307
# Length               0
# Diameter             0
# Height               2
# Whole_weight         0
# Shucked_weight       0
# Viscera_weight       0
# Shell_weight         0
# Rings                0
# dtype: int64

# %% [markdown]
# #### Height(높이)가 0 값이 나오는 것은 이상치로 판단

# %%
# 이상치의 개수가 적은 Glucose, BloodPressure, BMI의 경우 이상치 제거
print("제거 전 데이터 개수: ", len(df))
df = df[(df['Height'] != 0)]
print("제거 후 데이터 개수: ", len(df))
# Out:
# 제거 전 데이터 개수:  4177
# 제거 후 데이터 개수:  4175

# %% [markdown]
# 2개의 데이터 제거

# %%
# Rings 시각화
sns.countplot(data = df, x="Rings")
plt.xlabel("Rings")
plt.ylabel("Count")
plt.title("Abalone")

plt.show()

# %%
y = df['Rings']
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4175, dtype: int64

# %%
X = df.drop('Rings', axis=1)
X
# Out:
#       Sex_encoded  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0               2   0.455     0.365   0.095        0.5140          0.2245
# 1               2   0.350     0.265   0.090        0.2255          0.0995
# 2               0   0.530     0.420   0.135        0.6770          0.2565
# 3               2   0.440     0.365   0.125        0.5160          0.2155
# 4               1   0.330     0.255   0.080        0.2050          0.0895
# ...           ...     ...       ...     ...           ...             ...
# 4172            0   0.565     0.450   0.165        0.8870          0.3700
# 4173            2   0.590     0.440   0.135        0.9660          0.4390
# 4174            2   0.600     0.475   0.205        1.1760          0.5255
# 4175            0   0.625     0.485   0.150        1.0945          0.5310
# 4176            2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# 3             0.1140        0.1550
# 4             0.0395        0.0550
# ...              ...           ...
# 4172          0.2390        0.2490
# 4173          0.2145        0.2605
# 4174          0.2875        0.3080
# 4175          0.2610        0.2960
# 4176          0.3765        0.4950
#
# [4175 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=32)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((2672, 8), (835, 8), (2672,), (835,), (668, 8), (668,))

# %%
# 표준화 StandardScaler 
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
ss.fit(X_train)
train_scaled = ss.transform(X_train)
val_scaled = ss.transform(X_val)
test_scaled = ss.transform(X_test)

# %% [markdown]
# ## DL Model (ANN)
# - Rings_binned는 세 가지 값을 가지므로 One-hot encoding을 진행함
# - 3진 분류의 문제이므로 Output은 3개의 뉴런
# - 마찬가지로 3진 분류이므로 activation 함수는 softmax, loss function은 categorical_crossentropy 사용

# %%
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(Dense(1, activation='linear', input_shape=(8,)))  # 회귀를 위한 'linear' 활성화 함수 사용
model.compile(loss='mse', optimizer='adam', metrics=['mse'])  # 손실 함수 'mse' 사용
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 9
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

train_epochs = 50
history = model.fit(train_scaled, y_train, epochs=train_epochs, batch_size=batch_size, validation_data=(val_scaled, y_val), verbose=True, shuffle=True)
# Out:
# Epoch 1/50
# 167/167 [==============================] - 1s 2ms/step - loss: 106.0830 - mse: 106.0830 - val_loss: 113.9824 - val_mse: 113.9824
# Epoch 2/50
# 167/167 [==============================] - 0s 1ms/step - loss: 100.6988 - mse: 100.6988 - val_loss: 108.3111 - val_mse: 108.3111
# Epoch 3/50
# 167/167 [==============================] - 0s 1ms/step - loss: 96.3868 - mse: 96.3868 - val_loss: 103.6980 - val_mse: 103.6980
# Epoch 4/50
# 167/167 [==============================] - 0s 1ms/step - loss: 92.7075 - mse: 92.7075 - val_loss: 99.7773 - val_mse: 99.7773
# Epoch 5/50
# 167/167 [==============================] - 0s 1ms/step - loss: 89.4205 - mse: 89.4205 - val_loss: 96.2113 - val_mse: 96.2113
# Epoch 6/50
# 167/167 [==============================] - 0s 1ms/step - loss: 86.3702 - mse: 86.3702 - val_loss: 92.9815 - val_mse: 92.9815
# Epoch 7/50
# 167/167 [==============================] - 0s 1ms/step - loss: 83.4623 - mse: 83.4623 - val_loss: 89.8739 - val_mse: 89.8739
# Epoch 8/50
# 167/167 [==============================] - 0s 1ms/step - loss: 80.6549 - mse: 80.6549 - val_loss: 86.8896 - val_mse: 86.8896
# Epoch 9/50
# 167/167 [==============================] - 0s 1ms/step - loss: 77.9306 - mse: 77.9306 - val_loss: 84.0397 - val_mse: 84.0397
# Epoch 10/50
# 167/167 [==============================] - 0s 1ms/step - loss: 75.2815 - mse: 75.2815 - val_loss: 81.2817 - val_mse: 81.2817
# Epoch 11/50
# 167/167 [==============================] - 0s 1ms/step - loss: 72.7048 - mse: 72.7048 - val_loss: 78.5535 - val_mse: 78.5535
# Epoch 12/50
# 167/167 [==============================] - 0s 1ms/step - loss: 70.1753 - mse: 70.1753 - val_loss: 75.9583 - val_mse: 75.9583
# Epoch 13/50
# 167/167 [==============================] - 0s 1ms/step - loss: 67.7214 - mse: 67.7214 - val_loss: 73.4033 - val_mse: 73.4033
# Epoch 14/50
# 167/167 [==============================] - 0s 1ms/step - loss: 65.3179 - mse: 65.3179 - val_loss: 70.9120 - val_mse: 70.9120
# Epoch 15/50
# 167/167 [==============================] - 0s 1ms/step - loss: 62.9724 - mse: 62.9724 - val_loss: 68.4895 - val_mse: 68.4895
# Epoch 16/50
# 167/167 [==============================] - 0s 1ms/step - loss: 60.6864 - mse: 60.6864 - val_loss: 66.0858 - val_mse: 66.0858
# Epoch 17/50
# 167/167 [==============================] - 0s 1ms/step - loss: 58.4571 - mse: 58.4571 - val_loss: 63.7658 - val_mse: 63.7658
# Epoch 18/50
# 167/167 [==============================] - 0s 2ms/step - loss: 56.2858 - mse: 56.2858 - val_loss: 61.5143 - val_mse: 61.5143
# Epoch 19/50
# 167/167 [==============================] - 0s 1ms/step - loss: 54.1644 - mse: 54.1644 - val_loss: 59.3070 - val_mse: 59.3070
# Epoch 20/50
# 167/167 [==============================] - 0s 1ms/step - loss: 52.1008 - mse: 52.1008 - val_loss: 57.1464 - val_mse: 57.1464
# Epoch 21/50
# 167/167 [==============================] - 0s 1ms/step - loss: 50.0836 - mse: 50.0836 - val_loss: 55.0418 - val_mse: 55.0418
# Epoch 22/50
# 167/167 [==============================] - 0s 1ms/step - loss: 48.1227 - mse: 48.1227 - val_loss: 53.0021 - val_mse: 53.0021
# Epoch 23/50
# 167/167 [==============================] - 0s 1ms/step - loss: 46.2101 - mse: 46.2101 - val_loss: 50.9973 - val_mse: 50.9973
# Epoch 24/50
# 167/167 [==============================] - 0s 1ms/step - loss: 44.3506 - mse: 44.3506 - val_loss: 49.0528 - val_mse: 49.0528
# Epoch 25/50
# 167/167 [==============================] - 0s 1ms/step - loss: 42.5477 - mse: 42.5477 - val_loss: 47.1472 - val_mse: 47.1472
# Epoch 26/50
# 167/167 [==============================] - 0s 1ms/step - loss: 40.7832 - mse: 40.7832 - val_loss: 45.3026 - val_mse: 45.3026
# Epoch 27/50
# 167/167 [==============================] - 0s 1ms/step - loss: 39.0813 - mse: 39.0813 - val_loss: 43.4987 - val_mse: 43.4987
# Epoch 28/50
# 167/167 [==============================] - 0s 2ms/step - loss: 37.4165 - mse: 37.4165 - val_loss: 41.7657 - val_mse: 41.7657
# Epoch 29/50
# 167/167 [==============================] - 0s 1ms/step - loss: 35.8022 - mse: 35.8022 - val_loss: 40.0517 - val_mse: 40.0517
# Epoch 30/50
# 167/167 [==============================] - 0s 2ms/step - loss: 34.2459 - mse: 34.2459 - val_loss: 38.4373 - val_mse: 38.4373
# Epoch 31/50
# 167/167 [==============================] - 0s 1ms/step - loss: 32.7201 - mse: 32.7201 - val_loss: 36.8326 - val_mse: 36.8326
# Epoch 32/50
# 167/167 [==============================] - 0s 1ms/step - loss: 31.2519 - mse: 31.2519 - val_loss: 35.2611 - val_mse: 35.2611
# Epoch 33/50
# 167/167 [==============================] - 0s 2ms/step - loss: 29.8274 - mse: 29.8274 - val_loss: 33.7481 - val_mse: 33.7481
# Epoch 34/50
# 167/167 [==============================] - 0s 1ms/step - loss: 28.4490 - mse: 28.4490 - val_loss: 32.3102 - val_mse: 32.3102
# Epoch 35/50
# 167/167 [==============================] - 0s 1ms/step - loss: 27.1154 - mse: 27.1154 - val_loss: 30.9026 - val_mse: 30.9026
# Epoch 36/50
# 167/167 [==============================] - 0s 1ms/step - loss: 25.8347 - mse: 25.8347 - val_loss: 29.5615 - val_mse: 29.5615
# Epoch 37/50
# 167/167 [==============================] - 0s 1ms/step - loss: 24.5919 - mse: 24.5919 - val_loss: 28.2289 - val_mse: 28.2289
# Epoch 38/50
# 167/167 [==============================] - 0s 1ms/step - loss: 23.3940 - mse: 23.3940 - val_loss: 26.9599 - val_mse: 26.9599
# Epoch 39/50
# 167/167 [==============================] - 0s 1ms/step - loss: 22.2424 - mse: 22.2424 - val_loss: 25.7319 - val_mse: 25.7319
# Epoch 40/50
# 167/167 [==============================] - 0s 1ms/step - loss: 21.1342 - mse: 21.1342 - val_loss: 24.5162 - val_mse: 24.5162
# Epoch 41/50
# 167/167 [==============================] - 0s 1ms/step - loss: 20.0741 - mse: 20.0741 - val_loss: 23.3940 - val_mse: 23.3940
# Epoch 42/50
# 167/167 [==============================] - 0s 1ms/step - loss: 19.0512 - mse: 19.0512 - val_loss: 22.2898 - val_mse: 22.2898
# Epoch 43/50
# 167/167 [==============================] - 0s 1ms/step - loss: 18.0730 - mse: 18.0730 - val_loss: 21.2242 - val_mse: 21.2242
# Epoch 44/50
# 167/167 [==============================] - 0s 1ms/step - loss: 17.1372 - mse: 17.1372 - val_loss: 20.2293 - val_mse: 20.2293
# Epoch 45/50
# 167/167 [==============================] - 0s 1ms/step - loss: 16.2440 - mse: 16.2440 - val_loss: 19.2677 - val_mse: 19.2677
# Epoch 46/50
# 167/167 [==============================] - 0s 1ms/step - loss: 15.3929 - mse: 15.3929 - val_loss: 18.3407 - val_mse: 18.3407
# Epoch 47/50
# 167/167 [==============================] - 0s 3ms/step - loss: 14.5789 - mse: 14.5789 - val_loss: 17.4529 - val_mse: 17.4529
# Epoch 48/50
# 167/167 [==============================] - 0s 2ms/step - loss: 13.8079 - mse: 13.8079 - val_loss: 16.6083 - val_mse: 16.6083
# Epoch 49/50
# 167/167 [==============================] - 0s 2ms/step - loss: 13.0774 - mse: 13.0774 - val_loss: 15.8186 - val_mse: 15.8186
# Epoch 50/50
# 167/167 [==============================] - 0s 2ms/step - loss: 12.3822 - mse: 12.3822 - val_loss: 15.0443 - val_mse: 15.0443

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model MSE Loss')  # 'model loss'를 'Model MSE Loss'로 변경
plt.ylabel('MSE Loss')  # y축 레이블을 'MSE Loss'로 변경
plt.xlabel('Epoch')  # x축 레이블은 'Epoch' 그대로 유지
plt.legend(['Train', 'Validation'], loc='upper left')  # 범례 그대로 유지
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# 모델이 예측한 연속적인 값 (회귀)
predy = model.predict(test_scaled)

# 성능 지표 계산 (MSE, MAE, R^2)
mse = mean_squared_error(y_test, predy)
mae = mean_absolute_error(y_test, predy)
r2 = r2_score(y_test, predy)

print(f'MSE: {mse}')
print(f'MAE: {mae}')
print(f'R^2 Score: {r2}')

# 예측값 vs 실제값 시각화
plt.scatter(y_test, predy, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.title('Actual vs Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# 27/27 [==============================] - 0s 849us/step
# MSE: 13.31371095319527
# MAE: 2.737755744614287
# R^2 Score: -0.26411263393880446
# Text(0, 0.5, 'Predicted Values')

# %% [markdown]
# ## DL_Model(DNN)

# %%
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(Dense(15, activation='relu', input_shape=(8,)))
model.add(Dense(30, activation='relu'))
model.add(Dense(45, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(15, activation='relu'))

model.add(Dense(1, activation='linear'))
model.compile(loss='mse', optimizer='adam', metrics=['mse'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 15)                135
#
#  dense_2 (Dense)             (None, 30)                480
#
#  dense_3 (Dense)             (None, 45)                1395
#
#  dense_4 (Dense)             (None, 30)                1380
#
#  dense_5 (Dense)             (None, 15)                465
#
#  dense_6 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 3,871
# Trainable params: 3,871
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

train_epochs = 50
history = model.fit(train_scaled, y_train, epochs=train_epochs, batch_size=batch_size, validation_data=(val_scaled, y_val), verbose=True, shuffle=True)
# Out:
# Epoch 1/50
# 167/167 [==============================] - 1s 3ms/step - loss: 39.3851 - mse: 39.3851 - val_loss: 8.7353 - val_mse: 8.7353
# Epoch 2/50
# 167/167 [==============================] - 0s 2ms/step - loss: 9.5725 - mse: 9.5725 - val_loss: 6.4612 - val_mse: 6.4612
# Epoch 3/50
# 167/167 [==============================] - 0s 2ms/step - loss: 7.3797 - mse: 7.3797 - val_loss: 6.0889 - val_mse: 6.0889
# Epoch 4/50
# 167/167 [==============================] - 0s 2ms/step - loss: 6.2755 - mse: 6.2755 - val_loss: 5.9800 - val_mse: 5.9800
# Epoch 5/50
# 167/167 [==============================] - 0s 2ms/step - loss: 5.6879 - mse: 5.6879 - val_loss: 5.5661 - val_mse: 5.5661
# Epoch 6/50
# 167/167 [==============================] - 0s 3ms/step - loss: 5.3236 - mse: 5.3236 - val_loss: 5.6477 - val_mse: 5.6477
# Epoch 7/50
# 167/167 [==============================] - 0s 2ms/step - loss: 5.1191 - mse: 5.1191 - val_loss: 5.5258 - val_mse: 5.5258
# Epoch 8/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.8854 - mse: 4.8854 - val_loss: 5.3899 - val_mse: 5.3899
# Epoch 9/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.7942 - mse: 4.7942 - val_loss: 5.3624 - val_mse: 5.3624
# Epoch 10/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.6711 - mse: 4.6711 - val_loss: 5.3467 - val_mse: 5.3467
# Epoch 11/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.5633 - mse: 4.5633 - val_loss: 5.2770 - val_mse: 5.2770
# Epoch 12/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.5664 - mse: 4.5664 - val_loss: 5.2694 - val_mse: 5.2694
# Epoch 13/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.4914 - mse: 4.4914 - val_loss: 5.2653 - val_mse: 5.2653
# Epoch 14/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.4256 - mse: 4.4256 - val_loss: 5.1940 - val_mse: 5.1940
# Epoch 15/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.4416 - mse: 4.4416 - val_loss: 5.2301 - val_mse: 5.2301
# Epoch 16/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.3773 - mse: 4.3773 - val_loss: 6.6543 - val_mse: 6.6543
# Epoch 17/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.3721 - mse: 4.3721 - val_loss: 5.2783 - val_mse: 5.2783
# Epoch 18/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.3495 - mse: 4.3495 - val_loss: 5.2723 - val_mse: 5.2723
# Epoch 19/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.3055 - mse: 4.3055 - val_loss: 5.6642 - val_mse: 5.6642
# Epoch 20/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.3450 - mse: 4.3450 - val_loss: 5.2258 - val_mse: 5.2258
# Epoch 21/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.2962 - mse: 4.2962 - val_loss: 5.8784 - val_mse: 5.8784
# Epoch 22/50
# 167/167 [==============================] - 0s 3ms/step - loss: 4.2864 - mse: 4.2864 - val_loss: 5.2649 - val_mse: 5.2649
# Epoch 23/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.2750 - mse: 4.2750 - val_loss: 5.1566 - val_mse: 5.1566
# Epoch 24/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.2130 - mse: 4.2130 - val_loss: 5.2019 - val_mse: 5.2019
# Epoch 25/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1746 - mse: 4.1746 - val_loss: 5.3120 - val_mse: 5.3120
# Epoch 26/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.3036 - mse: 4.3036 - val_loss: 5.4912 - val_mse: 5.4912
# Epoch 27/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.2084 - mse: 4.2084 - val_loss: 5.1317 - val_mse: 5.1317
# Epoch 28/50
# 167/167 [==============================] - 0s 3ms/step - loss: 4.2553 - mse: 4.2553 - val_loss: 5.4592 - val_mse: 5.4592
# Epoch 29/50
# 167/167 [==============================] - 0s 3ms/step - loss: 4.1781 - mse: 4.1781 - val_loss: 5.3955 - val_mse: 5.3955
# Epoch 30/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1762 - mse: 4.1762 - val_loss: 5.4277 - val_mse: 5.4277
# Epoch 31/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.2021 - mse: 4.2021 - val_loss: 5.1744 - val_mse: 5.1744
# Epoch 32/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.2199 - mse: 4.2199 - val_loss: 5.2025 - val_mse: 5.2025
# Epoch 33/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1733 - mse: 4.1733 - val_loss: 5.2853 - val_mse: 5.2853
# Epoch 34/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1312 - mse: 4.1312 - val_loss: 5.2958 - val_mse: 5.2958
# Epoch 35/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1508 - mse: 4.1508 - val_loss: 5.0636 - val_mse: 5.0636
# Epoch 36/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1480 - mse: 4.1480 - val_loss: 5.6463 - val_mse: 5.6463
# Epoch 37/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1114 - mse: 4.1114 - val_loss: 5.2319 - val_mse: 5.2319
# Epoch 38/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1036 - mse: 4.1036 - val_loss: 5.2360 - val_mse: 5.2360
# Epoch 39/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1148 - mse: 4.1148 - val_loss: 5.1632 - val_mse: 5.1632
# Epoch 40/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1204 - mse: 4.1204 - val_loss: 5.1717 - val_mse: 5.1717
# Epoch 41/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.0996 - mse: 4.0996 - val_loss: 5.7778 - val_mse: 5.7778
# Epoch 42/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1922 - mse: 4.1922 - val_loss: 5.0565 - val_mse: 5.0565
# Epoch 43/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1159 - mse: 4.1159 - val_loss: 5.4375 - val_mse: 5.4375
# Epoch 44/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.0711 - mse: 4.0711 - val_loss: 5.5748 - val_mse: 5.5748
# Epoch 45/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.0418 - mse: 4.0418 - val_loss: 5.0410 - val_mse: 5.0410
# Epoch 46/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.0549 - mse: 4.0549 - val_loss: 5.1172 - val_mse: 5.1172
# Epoch 47/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1449 - mse: 4.1449 - val_loss: 5.2829 - val_mse: 5.2829
# Epoch 48/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.0971 - mse: 4.0971 - val_loss: 5.6340 - val_mse: 5.6340
# Epoch 49/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.1802 - mse: 4.1802 - val_loss: 5.0511 - val_mse: 5.0511
# Epoch 50/50
# 167/167 [==============================] - 0s 2ms/step - loss: 4.0743 - mse: 4.0743 - val_loss: 5.1238 - val_mse: 5.1238

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model MSE Loss')  # 'model loss'를 'Model MSE Loss'로 변경
plt.ylabel('MSE Loss')  # y축 레이블을 'MSE Loss'로 변경
plt.xlabel('Epoch')  # x축 레이블은 'Epoch' 그대로 유지
plt.legend(['Train', 'Validation'], loc='upper left')  # 범례 그대로 유지
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# 모델이 예측한 연속적인 값 (회귀)
predy = model.predict(test_scaled)

# 성능 지표 계산 (MSE, MAE, R^2)
mse = mean_squared_error(y_test, predy)
mae = mean_absolute_error(y_test, predy)
r2 = r2_score(y_test, predy)

print(f'MSE: {mse}')
print(f'MAE: {mae}')
print(f'R^2 Score: {r2}')

# 예측값 vs 실제값 시각화
plt.scatter(y_test, predy, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.title('Actual vs Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()
# Out:
# 27/27 [==============================] - 0s 1ms/step
# MSE: 4.63648037799161
# MAE: 1.4762844339816157
# R^2 Score: 0.559774623060904
