# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/AI_study/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# 데이터 정보 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ## Features
# - Pregnacies : 임신 횟수
# - Glucose: 혈당 수치
# - BloodPressure: 혈압 (mm Hg)
# - SkinThickness: 피부 두께 (mm)
# - Insulin: 인슐린 수치 (mu U/ml)
# - BMI (Body Mass Index): 체질량 지수
# - DiabetesPedigreeFunction: 당뇨병 유전력 함수
# - Age: 나이
# - Outcome: 당뇨병 여부 (0 or 1) - label

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# 데이터 결측치 확인
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# Outcome 개수 시각화
sns.countplot(data = df, x="Outcome", palette=["#1f77b4", "#ff7f0e"])
plt.xlabel("Diabetes or Not")
plt.ylabel("Count")
plt.title("Diabetes")

plt.show()
# Out:
# C:\Users\yc_hur\AppData\Local\Temp\ipykernel_28564\4103535089.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df, x="Outcome", palette=["#1f77b4", "#ff7f0e"])

# %%
#상관관계 히트맵 생성
#상관 관계 행렬
df_corr=df.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %% [markdown]
# ## Class인 Outcome과 높은 상관 관계를 맺는 features
# - Pregnancies(0.22)
# - Glucose(0.47)
# - BMI(0.29)
# - Age(0.24)

# %%
df.hist(bins=50, figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'Pregnancies'}>,
#         <Axes: title={'center': 'Glucose'}>,
#         <Axes: title={'center': 'BloodPressure'}>],
#        [<Axes: title={'center': 'SkinThickness'}>,
#         <Axes: title={'center': 'Insulin'}>,
#         <Axes: title={'center': 'BMI'}>],
#        [<Axes: title={'center': 'DiabetesPedigreeFunction'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Outcome'}>]], dtype=object)

# %%
# BMI와 SkinThickness 관계
plt.scatter(df['BMI'], df['SkinThickness'])
plt.xlabel('BMI')
plt.ylabel('SkinThickness')

plt.show()

# %%
# 각 열에서 0인 값의 개수를 확인
zero_values_count = (df == 0).sum()

# 결과 출력
print(zero_values_count)
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %% [markdown]
# #### Glucose(혈당 수치), BloodPressure(혈압), SkinThickness(피부 두께), Insulin(인슐린 수치), BMI(체질량 지수)가 0 값이 나오는 것은 이상치로 판단

# %%
# 이상치의 개수가 적은 Glucose, BloodPressure, BMI의 경우 이상치 제거
print("제거 전 데이터 개수: ", len(df))
df = df[(df['Glucose'] != 0) & 
        (df['BloodPressure'] != 0) & 
        (df['BMI'] != 0)]
print("제거 후 데이터 개수: ", len(df))
# Out:
# 제거 전 데이터 개수:  768
# 제거 후 데이터 개수:  724

# %% [markdown]
# 42개의 데이터 제거

# %% [markdown]
# Skin Thickness, BMI의 경우 이상치를 가진 데이터가 많고, 이상치를 제외하면 정규 분포를 따르기 때문에 평균값으로 대체

# %%
# 평균에 0인 값이 포함되면 평균치가 달라지므로 0인 값을 NaN으로 대체한 후 평균 계산후 대체
# SkinThickness와 Insulin의 0을 NaN으로 변경
df[['SkinThickness', 'Insulin']] = df[['SkinThickness', 'Insulin']].replace(0, np.nan)

# SkinThickness와 Insulin의 NaN 값을 평균값으로 대체
df['SkinThickness'] = df['SkinThickness'].fillna(df['SkinThickness'].mean())
df['Insulin'] = df['Insulin'].fillna(df['Insulin'].mean())
# Out:
# C:\Users\yc_hur\AppData\Local\Temp\ipykernel_28564\71297009.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['SkinThickness', 'Insulin']] = df[['SkinThickness', 'Insulin']].replace(0, np.nan)
# C:\Users\yc_hur\AppData\Local\Temp\ipykernel_28564\71297009.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SkinThickness'] = df['SkinThickness'].fillna(df['SkinThickness'].mean())
# C:\Users\yc_hur\AppData\Local\Temp\ipykernel_28564\71297009.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Insulin'] = df['Insulin'].fillna(df['Insulin'].mean())

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   724.000000  724.000000     724.000000     724.000000  724.000000
# mean      3.866022  121.882597      72.400552      29.182331  156.056122
# std       3.362803   30.750030      12.379870       9.018907   87.395294
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      25.000000  118.250000
# 50%       3.000000  117.000000      72.000000      29.182331  156.056122
# 75%       6.000000  142.000000      80.000000      33.000000  156.056122
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  724.000000                724.000000  724.000000  724.000000
# mean    32.467127                  0.474765   33.350829    0.343923
# std      6.888941                  0.332315   11.765393    0.475344
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.245000   24.000000    0.000000
# 50%     32.400000                  0.379000   29.000000    0.000000
# 75%     36.600000                  0.627500   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.hist(bins=50, figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'Pregnancies'}>,
#         <Axes: title={'center': 'Glucose'}>,
#         <Axes: title={'center': 'BloodPressure'}>],
#        [<Axes: title={'center': 'SkinThickness'}>,
#         <Axes: title={'center': 'Insulin'}>,
#         <Axes: title={'center': 'BMI'}>],
#        [<Axes: title={'center': 'DiabetesPedigreeFunction'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Outcome'}>]], dtype=object)

# %%
y = df['Outcome']
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 724, dtype: int64

# %%
X = df.drop('Outcome', axis=1)
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6      148             72      35.000000  156.056122  33.6
# 1              1       85             66      29.000000  156.056122  26.6
# 2              8      183             64      29.182331  156.056122  23.3
# 3              1       89             66      23.000000   94.000000  28.1
# 4              0      137             40      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10      101             76      48.000000  180.000000  32.9
# 764            2      122             70      27.000000  156.056122  36.8
# 765            5      121             72      23.000000  112.000000  26.2
# 766            1      126             60      29.182331  156.056122  30.1
# 767            1       93             70      31.000000  156.056122  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [724 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=32)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train, random_state=32)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((463, 8), (145, 8), (463,), (145,))

# %%
# 표준화 StandardScaler 
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
ss.fit(X_train)
train_scaled = ss.transform(X_train)
val_scaled = ss.transform(X_val)
test_scaled = ss.transform(X_test)

# %% [markdown]
# ## DL Model (ANN)
# - Outcome은 0과 1로 구성되어 있으므로 따로 One-hot encoding 진행 X
# - 2진 분류의 문제이므로 Output은 1개의 뉴런 (출력 값이 1일 확률)
# - 마찬가지로 2진 분류이므로 activation 함수는 sigmoid, loss function은 binary_crossentropy 사용

# %%
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(Dense(1, activation='sigmoid', input_shape=(8,)))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 9
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
# validation_split = 0.1
batch_size = 16

train_epochs = 50
history = model.fit(train_scaled, y_train, epochs=train_epochs, batch_size=batch_size, validation_data=(val_scaled, y_val), verbose=True, shuffle=True)
# Out:
# Epoch 1/50
# 29/29 [==============================] - 2s 10ms/step - loss: 1.0877 - accuracy: 0.3585 - val_loss: 1.3263 - val_accuracy: 0.2759
# Epoch 2/50
# 29/29 [==============================] - 0s 4ms/step - loss: 1.0458 - accuracy: 0.3693 - val_loss: 1.2685 - val_accuracy: 0.2759
# Epoch 3/50
# 29/29 [==============================] - 0s 4ms/step - loss: 1.0066 - accuracy: 0.3801 - val_loss: 1.2120 - val_accuracy: 0.2931
# Epoch 4/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.9692 - accuracy: 0.3823 - val_loss: 1.1597 - val_accuracy: 0.2845
# Epoch 5/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.9336 - accuracy: 0.4017 - val_loss: 1.1120 - val_accuracy: 0.3103
# Epoch 6/50
# 29/29 [==============================] - 0s 6ms/step - loss: 0.9012 - accuracy: 0.4125 - val_loss: 1.0640 - val_accuracy: 0.3276
# Epoch 7/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.8704 - accuracy: 0.4233 - val_loss: 1.0194 - val_accuracy: 0.3362
# Epoch 8/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.8414 - accuracy: 0.4320 - val_loss: 0.9793 - val_accuracy: 0.3621
# Epoch 9/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.8154 - accuracy: 0.4341 - val_loss: 0.9395 - val_accuracy: 0.3793
# Epoch 10/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.7903 - accuracy: 0.4514 - val_loss: 0.9048 - val_accuracy: 0.4138
# Epoch 11/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.7679 - accuracy: 0.4687 - val_loss: 0.8719 - val_accuracy: 0.4224
# Epoch 12/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.7472 - accuracy: 0.4989 - val_loss: 0.8410 - val_accuracy: 0.4483
# Epoch 13/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.7282 - accuracy: 0.5335 - val_loss: 0.8125 - val_accuracy: 0.4741
# Epoch 14/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.7106 - accuracy: 0.5680 - val_loss: 0.7871 - val_accuracy: 0.5000
# Epoch 15/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6946 - accuracy: 0.5896 - val_loss: 0.7638 - val_accuracy: 0.5517
# Epoch 16/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6799 - accuracy: 0.6112 - val_loss: 0.7428 - val_accuracy: 0.5690
# Epoch 17/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6665 - accuracy: 0.6242 - val_loss: 0.7224 - val_accuracy: 0.6034
# Epoch 18/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6541 - accuracy: 0.6436 - val_loss: 0.7032 - val_accuracy: 0.6121
# Epoch 19/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6428 - accuracy: 0.6566 - val_loss: 0.6862 - val_accuracy: 0.6466
# Epoch 20/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6326 - accuracy: 0.6652 - val_loss: 0.6701 - val_accuracy: 0.6466
# Epoch 21/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6227 - accuracy: 0.6674 - val_loss: 0.6564 - val_accuracy: 0.6552
# Epoch 22/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6141 - accuracy: 0.6760 - val_loss: 0.6436 - val_accuracy: 0.6638
# Epoch 23/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6061 - accuracy: 0.6782 - val_loss: 0.6307 - val_accuracy: 0.6810
# Epoch 24/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5984 - accuracy: 0.6911 - val_loss: 0.6198 - val_accuracy: 0.6983
# Epoch 25/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5916 - accuracy: 0.6976 - val_loss: 0.6087 - val_accuracy: 0.7241
# Epoch 26/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5851 - accuracy: 0.7063 - val_loss: 0.5994 - val_accuracy: 0.7241
# Epoch 27/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5792 - accuracy: 0.7084 - val_loss: 0.5901 - val_accuracy: 0.7328
# Epoch 28/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5736 - accuracy: 0.7127 - val_loss: 0.5818 - val_accuracy: 0.7328
# Epoch 29/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5684 - accuracy: 0.7063 - val_loss: 0.5744 - val_accuracy: 0.7328
# Epoch 30/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5638 - accuracy: 0.7106 - val_loss: 0.5667 - val_accuracy: 0.7414
# Epoch 31/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.5591 - accuracy: 0.7063 - val_loss: 0.5598 - val_accuracy: 0.7414
# Epoch 32/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.5549 - accuracy: 0.7106 - val_loss: 0.5533 - val_accuracy: 0.7414
# Epoch 33/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5509 - accuracy: 0.7127 - val_loss: 0.5478 - val_accuracy: 0.7500
# Epoch 34/50
# 29/29 [==============================] - 0s 9ms/step - loss: 0.5473 - accuracy: 0.7127 - val_loss: 0.5421 - val_accuracy: 0.7500
# Epoch 35/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5437 - accuracy: 0.7192 - val_loss: 0.5367 - val_accuracy: 0.7586
# Epoch 36/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5405 - accuracy: 0.7106 - val_loss: 0.5318 - val_accuracy: 0.7586
# Epoch 37/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5374 - accuracy: 0.7149 - val_loss: 0.5271 - val_accuracy: 0.7586
# Epoch 38/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5343 - accuracy: 0.7192 - val_loss: 0.5233 - val_accuracy: 0.7672
# Epoch 39/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.5317 - accuracy: 0.7192 - val_loss: 0.5195 - val_accuracy: 0.7759
# Epoch 40/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5290 - accuracy: 0.7235 - val_loss: 0.5155 - val_accuracy: 0.7759
# Epoch 41/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5264 - accuracy: 0.7235 - val_loss: 0.5124 - val_accuracy: 0.7759
# Epoch 42/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5242 - accuracy: 0.7235 - val_loss: 0.5086 - val_accuracy: 0.7759
# Epoch 43/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5217 - accuracy: 0.7257 - val_loss: 0.5059 - val_accuracy: 0.7759
# Epoch 44/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5197 - accuracy: 0.7257 - val_loss: 0.5030 - val_accuracy: 0.7759
# Epoch 45/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5176 - accuracy: 0.7300 - val_loss: 0.5002 - val_accuracy: 0.7759
# Epoch 46/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.5156 - accuracy: 0.7343 - val_loss: 0.4973 - val_accuracy: 0.7759
# Epoch 47/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5138 - accuracy: 0.7365 - val_loss: 0.4950 - val_accuracy: 0.7759
# Epoch 48/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.5119 - accuracy: 0.7387 - val_loss: 0.4932 - val_accuracy: 0.7759
# Epoch 49/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5102 - accuracy: 0.7430 - val_loss: 0.4908 - val_accuracy: 0.7759
# Epoch 50/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.5086 - accuracy: 0.7451 - val_loss: 0.4886 - val_accuracy: 0.7759

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %% [markdown]
# 이진분류는 label이 1일 '확률'을 구하기 때문에 0.5를 기준으로 0과 1로 변환

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,f1_score

# 모델이 예측한 값 (클래스 1의 확률값)
predy = model.predict(test_scaled)

# 이진 분류 문제에서는 0.5를 기준으로 0과 1로 변환
predy = (predy > 0.5).astype(int)

# Confusion Matrix와 성능 지표 출력
LABELS = ['Normal', 'Diabetes']
cm = confusion_matrix(y_test, predy)
print(cm)
print(accuracy_score(y_test, predy))
print(f1_score(y_test, predy, average='weighted'))
print(classification_report(y_test, predy))

# Confusion Matrix 시각화
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt='.2f')
# Out:
# 5/5 [==============================] - 0s 2ms/step
# [[85 10]
#  [28 22]]
# 0.7379310344827587
# 0.7205068900821634
#               precision    recall  f1-score   support
#
#            0       0.75      0.89      0.82        95
#            1       0.69      0.44      0.54        50
#
#     accuracy                           0.74       145
#    macro avg       0.72      0.67      0.68       145
# weighted avg       0.73      0.74      0.72       145
# <Axes: >

# %%
from sklearn.metrics import roc_curve, auc

# 모델의 예측 확률을 사용 (predy는 이진 분류 확률값)
predy_proba = model.predict(test_scaled)

# 실제값과 예측 확률값을 사용하여 ROC 곡선 데이터 계산
fpr, tpr, thresholds = roc_curve(y_test, predy_proba)

# AUC 계산
roc_auc = auc(fpr, tpr)

# ROC 곡선 그리기
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='grey', lw=2, linestyle='--')  # 대각선 기준선
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %% [markdown]
# ## DL Model(DNN)

# %%
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(Dense(8, activation='relu', input_shape=(8,)))
model.add(Dense(12, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(12, activation='relu'))

model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 8)                 72
#
#  dense_2 (Dense)             (None, 12)                108
#
#  dense_3 (Dense)             (None, 16)                208
#
#  dense_4 (Dense)             (None, 12)                204
#
#  dense_5 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 605
# Trainable params: 605
# Non-trainable params: 0
# _________________________________________________________________

# %%
# validation_split = 0.1
batch_size = 64

train_epochs = 50
history = model.fit(train_scaled, y_train, epochs=train_epochs, batch_size=batch_size, validation_data=(val_scaled, y_val), verbose=True, shuffle=True)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 24ms/step - loss: 0.6596 - accuracy: 0.6631 - val_loss: 0.6465 - val_accuracy: 0.6638
# Epoch 2/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6389 - accuracy: 0.6847 - val_loss: 0.6273 - val_accuracy: 0.6724
# Epoch 3/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6226 - accuracy: 0.6890 - val_loss: 0.6088 - val_accuracy: 0.6638
# Epoch 4/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6073 - accuracy: 0.6911 - val_loss: 0.5911 - val_accuracy: 0.6638
# Epoch 5/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5936 - accuracy: 0.6955 - val_loss: 0.5745 - val_accuracy: 0.6724
# Epoch 6/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5794 - accuracy: 0.7127 - val_loss: 0.5586 - val_accuracy: 0.6810
# Epoch 7/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5669 - accuracy: 0.7171 - val_loss: 0.5428 - val_accuracy: 0.7241
# Epoch 8/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5555 - accuracy: 0.7171 - val_loss: 0.5284 - val_accuracy: 0.7328
# Epoch 9/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5448 - accuracy: 0.7192 - val_loss: 0.5170 - val_accuracy: 0.7328
# Epoch 10/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5353 - accuracy: 0.7300 - val_loss: 0.5066 - val_accuracy: 0.7328
# Epoch 11/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5266 - accuracy: 0.7235 - val_loss: 0.4967 - val_accuracy: 0.7500
# Epoch 12/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5190 - accuracy: 0.7387 - val_loss: 0.4896 - val_accuracy: 0.7414
# Epoch 13/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5107 - accuracy: 0.7473 - val_loss: 0.4859 - val_accuracy: 0.7328
# Epoch 14/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5046 - accuracy: 0.7495 - val_loss: 0.4809 - val_accuracy: 0.7500
# Epoch 15/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4972 - accuracy: 0.7559 - val_loss: 0.4748 - val_accuracy: 0.7500
# Epoch 16/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4907 - accuracy: 0.7603 - val_loss: 0.4717 - val_accuracy: 0.7414
# Epoch 17/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4852 - accuracy: 0.7538 - val_loss: 0.4692 - val_accuracy: 0.7500
# Epoch 18/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4787 - accuracy: 0.7559 - val_loss: 0.4699 - val_accuracy: 0.7500
# Epoch 19/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4739 - accuracy: 0.7538 - val_loss: 0.4716 - val_accuracy: 0.7500
# Epoch 20/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4687 - accuracy: 0.7581 - val_loss: 0.4710 - val_accuracy: 0.7500
# Epoch 21/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4637 - accuracy: 0.7603 - val_loss: 0.4712 - val_accuracy: 0.7500
# Epoch 22/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4598 - accuracy: 0.7624 - val_loss: 0.4712 - val_accuracy: 0.7500
# Epoch 23/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4563 - accuracy: 0.7646 - val_loss: 0.4733 - val_accuracy: 0.7500
# Epoch 24/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4528 - accuracy: 0.7689 - val_loss: 0.4746 - val_accuracy: 0.7500
# Epoch 25/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4494 - accuracy: 0.7689 - val_loss: 0.4751 - val_accuracy: 0.7500
# Epoch 26/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4476 - accuracy: 0.7667 - val_loss: 0.4755 - val_accuracy: 0.7500
# Epoch 27/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4462 - accuracy: 0.7689 - val_loss: 0.4759 - val_accuracy: 0.7500
# Epoch 28/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4430 - accuracy: 0.7732 - val_loss: 0.4812 - val_accuracy: 0.7414
# Epoch 29/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4432 - accuracy: 0.7754 - val_loss: 0.4837 - val_accuracy: 0.7414
# Epoch 30/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4392 - accuracy: 0.7732 - val_loss: 0.4805 - val_accuracy: 0.7500
# Epoch 31/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4372 - accuracy: 0.7732 - val_loss: 0.4819 - val_accuracy: 0.7500
# Epoch 32/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4356 - accuracy: 0.7797 - val_loss: 0.4845 - val_accuracy: 0.7500
# Epoch 33/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4361 - accuracy: 0.7819 - val_loss: 0.4845 - val_accuracy: 0.7500
# Epoch 34/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4326 - accuracy: 0.7883 - val_loss: 0.4880 - val_accuracy: 0.7414
# Epoch 35/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4333 - accuracy: 0.7775 - val_loss: 0.4874 - val_accuracy: 0.7328
# Epoch 36/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4314 - accuracy: 0.7819 - val_loss: 0.4919 - val_accuracy: 0.7328
# Epoch 37/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4301 - accuracy: 0.7862 - val_loss: 0.4891 - val_accuracy: 0.7328
# Epoch 38/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4286 - accuracy: 0.7927 - val_loss: 0.4901 - val_accuracy: 0.7328
# Epoch 39/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4279 - accuracy: 0.7948 - val_loss: 0.4886 - val_accuracy: 0.7500
# Epoch 40/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4268 - accuracy: 0.7927 - val_loss: 0.4906 - val_accuracy: 0.7500
# Epoch 41/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4255 - accuracy: 0.7927 - val_loss: 0.4926 - val_accuracy: 0.7414
# Epoch 42/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4238 - accuracy: 0.7883 - val_loss: 0.4942 - val_accuracy: 0.7328
# Epoch 43/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4230 - accuracy: 0.7927 - val_loss: 0.4926 - val_accuracy: 0.7414
# Epoch 44/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4220 - accuracy: 0.7948 - val_loss: 0.4932 - val_accuracy: 0.7414
# Epoch 45/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4212 - accuracy: 0.7905 - val_loss: 0.4963 - val_accuracy: 0.7414
# Epoch 46/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4207 - accuracy: 0.7883 - val_loss: 0.4976 - val_accuracy: 0.7414
# Epoch 47/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4191 - accuracy: 0.7927 - val_loss: 0.4957 - val_accuracy: 0.7328
# Epoch 48/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4188 - accuracy: 0.8035 - val_loss: 0.4946 - val_accuracy: 0.7328
# Epoch 49/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4175 - accuracy: 0.8099 - val_loss: 0.4965 - val_accuracy: 0.7328
# Epoch 50/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4163 - accuracy: 0.7948 - val_loss: 0.5046 - val_accuracy: 0.7241

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,f1_score

# 모델이 예측한 값 (클래스 1의 확률값)
predy = model.predict(test_scaled)

# 이진 분류 문제에서는 0.5를 기준으로 0과 1로 변환
predy = (predy > 0.5).astype(int)

# Confusion Matrix와 성능 지표 출력
LABELS = ['Normal', 'Diabetes']
cm = confusion_matrix(y_test, predy)
print(cm)
print(accuracy_score(y_test, predy))
print(f1_score(y_test, predy, average='weighted'))
print(classification_report(y_test, predy))

# Confusion Matrix 시각화
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt='.2f')
# Out:
# 5/5 [==============================] - 0s 1ms/step
# [[89  6]
#  [26 24]]
# 0.7793103448275862
# 0.7622331691297208
#               precision    recall  f1-score   support
#
#            0       0.77      0.94      0.85        95
#            1       0.80      0.48      0.60        50
#
#     accuracy                           0.78       145
#    macro avg       0.79      0.71      0.72       145
# weighted avg       0.78      0.78      0.76       145
# <Axes: >

# %%
from sklearn.metrics import roc_curve, auc

# 모델의 예측 확률을 사용 (predy는 이진 분류 확률값)
predy_proba = model.predict(test_scaled)

# 실제값과 예측 확률값을 사용하여 ROC 곡선 데이터 계산
fpr, tpr, thresholds = roc_curve(y_test, predy_proba)

# AUC 계산
roc_auc = auc(fpr, tpr)

# ROC 곡선 그리기
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='grey', lw=2, linestyle='--')  # 대각선 기준선
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# 5/5 [==============================] - 0s 2ms/step
