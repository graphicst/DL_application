# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from keras import layers

# %%
df = pd.read_csv("C:/AI_study/DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
df.columns
# Out:
# Index(['T_xacc_mean', 'T_xacc_max', 'T_xacc_min', 'T_xacc_var', 'T_xacc_std',
#        'T_xacc_skew', 'T_yacc_mean', 'T_yacc_max', 'T_yacc_min', 'T_yacc_var',
#        ...
#        'LL_ymag_std', 'LL_ymag_skew', 'LL_zmag_mean', 'LL_zmag_max',
#        'LL_zmag_min', 'LL_zmag_var', 'LL_zmag_std', 'LL_zmag_skew', 'activity',
#        'people'],
#       dtype='object', length=272)

# %%
df['activity'].value_counts()
# Out:
# lyingRigh                  480
# crossTrainer               480
# standingInElevatorStill    480
# runningTreadmill           480
# cyclingHorizontal          480
# jumping                    480
# walkingLot                 480
# walkingTreadmillIncline    480
# movingInElevator           480
# ascendingStairs            480
# sitting                    480
# basketBall                 480
# decendingStairs            480
# walkingTreadmillFlat       480
# cyclingVertical            480
# standing                   480
# lyingBack                  480
# rowing                     480
# stepper                    480
# Name: activity, dtype: int64

# %%
df = df.drop('people', axis=1)

# %%
# AE 실습을 위해 사용할 세 가지 값만 선택
df_filtered = df[df['activity'].isin(['lyingRigh', 'lyingBack', 'standingInElevatorStill'])]
df_filtered
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 960     -4.834646     -4.7185     -4.9049    0.001124    0.033529
# 961     -4.780810     -4.5850     -4.8833    0.003948    0.062835
# 962     -4.804400     -4.7037     -4.8755    0.001482    0.038496
# 963     -4.750563     -4.5696     -4.8977    0.004447    0.066683
# 964     -4.774916     -4.6741     -4.8457    0.001080    0.032868
# ...           ...         ...         ...         ...         ...
# 3355     9.802530      9.8423      9.6857    0.000865    0.029403
# 3356     9.799047      9.9038      9.7250    0.000750    0.027379
# 3357     9.797938      9.8537      9.7347    0.000576    0.023998
# 3358     9.606040      9.9302      9.1379    0.067806    0.260396
# 3359     9.722434     10.0250      9.1981    0.033530    0.183113
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 960      0.632141    -0.501018   -0.417440    -0.59561    0.001016  ...
# 961      1.052880    -0.480601   -0.403720    -0.63184    0.001297  ...
# 962      0.735226    -0.493925   -0.426160    -0.59561    0.000863  ...
# 963      0.710263    -0.437358   -0.308770    -0.55225    0.003587  ...
# 964      0.324779    -0.459456   -0.389000    -0.53714    0.001059  ...
# ...           ...          ...         ...         ...         ...  ...
# 3355    -1.341638    -0.185503   -0.090833    -0.25891    0.001316  ...
# 3356     0.468885    -0.200147   -0.113400    -0.29976    0.001781  ...
# 3357    -0.365021    -0.195523   -0.132300    -0.25615    0.001006  ...
# 3358    -0.719145    -0.188162   -0.119480    -0.25154    0.000760  ...
# 3359    -1.460862    -0.196782   -0.107560    -0.29148    0.001333  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 960   9.725263e-07     0.000986      0.074676     -0.532664     -0.52993
# 961   6.211659e-07     0.000788     -0.181526     -0.531169     -0.52940
# 962   4.579046e-07     0.000677     -0.263115     -0.530569     -0.52873
# 963   4.703523e-07     0.000686     -0.060925     -0.531167     -0.52962
# 964   5.467316e-07     0.000739      0.335811     -0.529804     -0.52706
# ...            ...          ...           ...           ...          ...
# 3355  4.094967e-05     0.006399     -0.962316      0.488304      0.51448
# 3356  3.938668e-05     0.006276     -0.513505      0.488314      0.51509
# 3357  3.456590e-05     0.005879      0.691562      0.486659      0.51104
# 3358  6.375183e-05     0.007984     -0.736630      0.490615      0.53319
# 3359  8.331086e-03     0.091275      0.017627      0.430436      0.59338
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew  \
# 960      -0.53521  9.585668e-07     0.000979     -0.193301
# 961      -0.53365  7.608973e-07     0.000872     -0.372381
# 962      -0.53222  5.160537e-07     0.000718      0.185587
# 963      -0.53283  4.975523e-07     0.000705     -0.145321
# 964      -0.53251  1.292131e-06     0.001137     -0.026271
# ...           ...           ...          ...           ...
# 3355      0.46222  5.126574e-05     0.007160     -0.717994
# 3356      0.46554  4.488257e-05     0.006699      0.136985
# 3357      0.46926  4.251657e-05     0.006520      0.178792
# 3358      0.46602  8.602620e-05     0.009275      1.175198
# 3359      0.25950  1.190307e-02     0.109101      0.143096
#
#                      activity
# 960                 lyingBack
# 961                 lyingBack
# 962                 lyingBack
# 963                 lyingBack
# 964                 lyingBack
# ...                       ...
# 3355  standingInElevatorStill
# 3356  standingInElevatorStill
# 3357  standingInElevatorStill
# 3358  standingInElevatorStill
# 3359  standingInElevatorStill
#
# [1440 rows x 271 columns]

# %%
df_filtered['activity'].value_counts()
# Out:
# lyingRigh                  480
# standingInElevatorStill    480
# lyingBack                  480
# Name: activity, dtype: int64

# %%
# 새로운 Class 컬럼 추가
df_filtered['Class'] = 'undefined'  # 우선 기본 값을 설정

# activity가 lyingRigh 또는 lyingBack인 경우 Class를 normal로 설정
df_filtered.loc[df['activity'].isin(['lyingRigh', 'lyingBack']), 'Class'] = 0

# activity가 jumping인 경우 Class를 abnormal로 설정
df_filtered.loc[df['activity'] == 'standingInElevatorStill', 'Class'] = 1

# 기존의 activity 행을 제거해서 df 변경
df = df_filtered.drop('activity', axis=1)

df
# Out:
# C:\Users\User\.conda\envs\test01\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\User\.conda\envs\test01\lib\site-packages\pandas\core\indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 960     -4.834646     -4.7185     -4.9049    0.001124    0.033529
# 961     -4.780810     -4.5850     -4.8833    0.003948    0.062835
# 962     -4.804400     -4.7037     -4.8755    0.001482    0.038496
# 963     -4.750563     -4.5696     -4.8977    0.004447    0.066683
# 964     -4.774916     -4.6741     -4.8457    0.001080    0.032868
# ...           ...         ...         ...         ...         ...
# 3355     9.802530      9.8423      9.6857    0.000865    0.029403
# 3356     9.799047      9.9038      9.7250    0.000750    0.027379
# 3357     9.797938      9.8537      9.7347    0.000576    0.023998
# 3358     9.606040      9.9302      9.1379    0.067806    0.260396
# 3359     9.722434     10.0250      9.1981    0.033530    0.183113
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 960      0.632141    -0.501018   -0.417440    -0.59561    0.001016  ...
# 961      1.052880    -0.480601   -0.403720    -0.63184    0.001297  ...
# 962      0.735226    -0.493925   -0.426160    -0.59561    0.000863  ...
# 963      0.710263    -0.437358   -0.308770    -0.55225    0.003587  ...
# 964      0.324779    -0.459456   -0.389000    -0.53714    0.001059  ...
# ...           ...          ...         ...         ...         ...  ...
# 3355    -1.341638    -0.185503   -0.090833    -0.25891    0.001316  ...
# 3356     0.468885    -0.200147   -0.113400    -0.29976    0.001781  ...
# 3357    -0.365021    -0.195523   -0.132300    -0.25615    0.001006  ...
# 3358    -0.719145    -0.188162   -0.119480    -0.25154    0.000760  ...
# 3359    -1.460862    -0.196782   -0.107560    -0.29148    0.001333  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 960   9.725263e-07     0.000986      0.074676     -0.532664     -0.52993
# 961   6.211659e-07     0.000788     -0.181526     -0.531169     -0.52940
# 962   4.579046e-07     0.000677     -0.263115     -0.530569     -0.52873
# 963   4.703523e-07     0.000686     -0.060925     -0.531167     -0.52962
# 964   5.467316e-07     0.000739      0.335811     -0.529804     -0.52706
# ...            ...          ...           ...           ...          ...
# 3355  4.094967e-05     0.006399     -0.962316      0.488304      0.51448
# 3356  3.938668e-05     0.006276     -0.513505      0.488314      0.51509
# 3357  3.456590e-05     0.005879      0.691562      0.486659      0.51104
# 3358  6.375183e-05     0.007984     -0.736630      0.490615      0.53319
# 3359  8.331086e-03     0.091275      0.017627      0.430436      0.59338
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew  Class
# 960      -0.53521  9.585668e-07     0.000979     -0.193301      0
# 961      -0.53365  7.608973e-07     0.000872     -0.372381      0
# 962      -0.53222  5.160537e-07     0.000718      0.185587      0
# 963      -0.53283  4.975523e-07     0.000705     -0.145321      0
# 964      -0.53251  1.292131e-06     0.001137     -0.026271      0
# ...           ...           ...          ...           ...    ...
# 3355      0.46222  5.126574e-05     0.007160     -0.717994      1
# 3356      0.46554  4.488257e-05     0.006699      0.136985      1
# 3357      0.46926  4.251657e-05     0.006520      0.178792      1
# 3358      0.46602  8.602620e-05     0.009275      1.175198      1
# 3359      0.25950  1.190307e-02     0.109101      0.143096      1
#
# [1440 rows x 271 columns]

# %%
df.shape
# Out:
# (1440, 271)

# %%
LABELS = ["Normal", "Abnormal"]

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
abnormal = df[df.Class == 1]
normal = df[df.Class == 0]
print(abnormal.shape)
print(normal.shape)
# Out:
# (480, 271)
# (960, 271)

# %%
RANDOM_SEED = 42

# %%
X_train, X_test = train_test_split(df, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

X_train.shape
# Out:
# (765, 270)

# %% [markdown]
# ## Symmetrci AE

# %%
# 오토인코더 모델

input_dim = X_train.shape[1]
encoding_dim = 32  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
encoded = Dense(int(encoding_dim / 4), activation='relu')(encoded)
encoded = Dense(int(encoding_dim / 8), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 8), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 4), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
# 3. 모델 학습
# 훈련데이터의 0.1 을 validation data로 사용
history = autoencoder.fit(X_train, X_train, 
                          epochs=50, 
                          batch_size=256, 
                          shuffle=True, 
                          validation_split = 0.1)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 0s 48ms/step - loss: 5.7517 - val_loss: 5.6963
# Epoch 2/50
# 3/3 [==============================] - 0s 8ms/step - loss: 5.7393 - val_loss: 5.6816
# Epoch 3/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.7209 - val_loss: 5.6589
# Epoch 4/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.6937 - val_loss: 5.6274
# Epoch 5/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.6581 - val_loss: 5.5864
# Epoch 6/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.6130 - val_loss: 5.5375
# Epoch 7/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.5609 - val_loss: 5.4833
# Epoch 8/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.5042 - val_loss: 5.4256
# Epoch 9/50
# 3/3 [==============================] - 0s 8ms/step - loss: 5.4446 - val_loss: 5.3665
# Epoch 10/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.3846 - val_loss: 5.3076
# Epoch 11/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.3253 - val_loss: 5.2505
# Epoch 12/50
# 3/3 [==============================] - 0s 6ms/step - loss: 5.2690 - val_loss: 5.1968
# Epoch 13/50
# 3/3 [==============================] - 0s 6ms/step - loss: 5.2175 - val_loss: 5.1480
# Epoch 14/50
# 3/3 [==============================] - 0s 8ms/step - loss: 5.1721 - val_loss: 5.1060
# Epoch 15/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.1342 - val_loss: 5.0708
# Epoch 16/50
# 3/3 [==============================] - 0s 10ms/step - loss: 5.1035 - val_loss: 5.0417
# Epoch 17/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0785 - val_loss: 5.0186
# Epoch 18/50
# 3/3 [==============================] - 0s 9ms/step - loss: 5.0594 - val_loss: 5.0015
# Epoch 19/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0450 - val_loss: 4.9886
# Epoch 20/50
# 3/3 [==============================] - 0s 8ms/step - loss: 5.0338 - val_loss: 4.9791
# Epoch 21/50
# 3/3 [==============================] - 0s 8ms/step - loss: 5.0256 - val_loss: 4.9723
# Epoch 22/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0198 - val_loss: 4.9671
# Epoch 23/50
# 3/3 [==============================] - 0s 8ms/step - loss: 5.0148 - val_loss: 4.9623
# Epoch 24/50
# 3/3 [==============================] - 0s 8ms/step - loss: 5.0098 - val_loss: 4.9571
# Epoch 25/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0046 - val_loss: 4.9515
# Epoch 26/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9988 - val_loss: 4.9458
# Epoch 27/50
# 3/3 [==============================] - 0s 8ms/step - loss: 4.9936 - val_loss: 4.9411
# Epoch 28/50
# 3/3 [==============================] - 0s 8ms/step - loss: 4.9899 - val_loss: 4.9381
# Epoch 29/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9872 - val_loss: 4.9357
# Epoch 30/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9848 - val_loss: 4.9331
# Epoch 31/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9821 - val_loss: 4.9296
# Epoch 32/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9784 - val_loss: 4.9240
# Epoch 33/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9725 - val_loss: 4.9165
# Epoch 34/50
# 3/3 [==============================] - 0s 8ms/step - loss: 4.9665 - val_loss: 4.9108
# Epoch 35/50
# 3/3 [==============================] - 0s 8ms/step - loss: 4.9628 - val_loss: 4.9079
# Epoch 36/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9609 - val_loss: 4.9064
# Epoch 37/50
# 3/3 [==============================] - 0s 8ms/step - loss: 4.9597 - val_loss: 4.9052
# Epoch 38/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9584 - val_loss: 4.9039
# Epoch 39/50
# 3/3 [==============================] - 0s 8ms/step - loss: 4.9568 - val_loss: 4.9025
# Epoch 40/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9549 - val_loss: 4.9012
# Epoch 41/50
# 3/3 [==============================] - 0s 6ms/step - loss: 4.9532 - val_loss: 4.9002
# Epoch 42/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9515 - val_loss: 4.8988
# Epoch 43/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9498 - val_loss: 4.8972
# Epoch 44/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9481 - val_loss: 4.8959
# Epoch 45/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9470 - val_loss: 4.8950
# Epoch 46/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9461 - val_loss: 4.8941
# Epoch 47/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9452 - val_loss: 4.8931
# Epoch 48/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9443 - val_loss: 4.8924
# Epoch 49/50
# 3/3 [==============================] - 0s 7ms/step - loss: 4.9436 - val_loss: 4.8918
# Epoch 50/50
# 3/3 [==============================] - 0s 6ms/step - loss: 4.9430 - val_loss: 4.8913

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨

predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
#        reconstruction_error
# count            288.000000
# mean               4.990508
# std                0.304487
# min                4.586983
# 25%                4.735293
# 50%                4.950556
# 75%                5.135221
# max                6.972876

# %%
error_df.head()
# Out:
#       reconstruction_error true_class
# 1128              5.040044          0
# 1565              5.017325          0
# 1508              5.156378          0
# 1025              5.474060          0
# 1588              5.016866          0

# %%
# threshold 값을 조정하여 최선의 정확도를 얻음, 그래프로를 보고 결정

threshold = 5

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Abnormal" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
error_df['true_class'] = error_df['true_class'].astype(int)

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.72      0.82       195
#            1       0.61      0.89      0.72        93
#
#     accuracy                           0.78       288
#    macro avg       0.77      0.81      0.77       288
# weighted avg       0.83      0.78      0.78       288

# %% [markdown]
# ## Asymmetric Autoencoder

# %%
# 오토인코더 모델

input_dim = X_train.shape[1]
encoding_dim = 32  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
encoded = Dense(int(encoding_dim / 4), activation='relu')(encoded)
encoded = Dense(int(encoding_dim / 8), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 4), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

Asy_autoencoder = Model(inputs=input_layer, outputs=decoded)
Asy_autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
# 3. 모델 학습
# 훈련데이터의 0.1 을 validation data로 사용
history = Asy_autoencoder.fit(X_train, X_train, 
                          epochs=50, 
                          batch_size=256, 
                          shuffle=True, 
                          validation_split = 0.1)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 0s 33ms/step - loss: 5.7662 - val_loss: 5.7110
# Epoch 2/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.7595 - val_loss: 5.7078
# Epoch 3/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.7567 - val_loss: 5.7053
# Epoch 4/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.7542 - val_loss: 5.7023
# Epoch 5/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.7509 - val_loss: 5.6983
# Epoch 6/50
# 3/3 [==============================] - 0s 6ms/step - loss: 5.7467 - val_loss: 5.6928
# Epoch 7/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.7409 - val_loss: 5.6854
# Epoch 8/50
# 3/3 [==============================] - 0s 6ms/step - loss: 5.7329 - val_loss: 5.6753
# Epoch 9/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.7218 - val_loss: 5.6615
# Epoch 10/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.7066 - val_loss: 5.6417
# Epoch 11/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.6845 - val_loss: 5.6141
# Epoch 12/50
# 3/3 [==============================] - 0s 6ms/step - loss: 5.6533 - val_loss: 5.5745
# Epoch 13/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.6113 - val_loss: 5.5257
# Epoch 14/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.5605 - val_loss: 5.4690
# Epoch 15/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.5025 - val_loss: 5.4072
# Epoch 16/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.4413 - val_loss: 5.3436
# Epoch 17/50
# 3/3 [==============================] - 0s 8ms/step - loss: 5.3786 - val_loss: 5.2813
# Epoch 18/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.3181 - val_loss: 5.2231
# Epoch 19/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.2619 - val_loss: 5.1716
# Epoch 20/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.2127 - val_loss: 5.1280
# Epoch 21/50
# 3/3 [==============================] - 0s 8ms/step - loss: 5.1711 - val_loss: 5.0931
# Epoch 22/50
# 3/3 [==============================] - 0s 6ms/step - loss: 5.1384 - val_loss: 5.0666
# Epoch 23/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.1139 - val_loss: 5.0478
# Epoch 24/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0965 - val_loss: 5.0352
# Epoch 25/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0850 - val_loss: 5.0269
# Epoch 26/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0775 - val_loss: 5.0217
# Epoch 27/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0728 - val_loss: 5.0184
# Epoch 28/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0698 - val_loss: 5.0161
# Epoch 29/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0677 - val_loss: 5.0143
# Epoch 30/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0662 - val_loss: 5.0132
# Epoch 31/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0651 - val_loss: 5.0124
# Epoch 32/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0641 - val_loss: 5.0117
# Epoch 33/50
# 3/3 [==============================] - 0s 8ms/step - loss: 5.0632 - val_loss: 5.0111
# Epoch 34/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0622 - val_loss: 5.0105
# Epoch 35/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0611 - val_loss: 5.0098
# Epoch 36/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0601 - val_loss: 5.0092
# Epoch 37/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0590 - val_loss: 5.0083
# Epoch 38/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0578 - val_loss: 5.0073
# Epoch 39/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0566 - val_loss: 5.0060
# Epoch 40/50
# 3/3 [==============================] - 0s 8ms/step - loss: 5.0553 - val_loss: 5.0044
# Epoch 41/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0537 - val_loss: 5.0025
# Epoch 42/50
# 3/3 [==============================] - 0s 6ms/step - loss: 5.0519 - val_loss: 5.0003
# Epoch 43/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0498 - val_loss: 4.9978
# Epoch 44/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0469 - val_loss: 4.9941
# Epoch 45/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0425 - val_loss: 4.9890
# Epoch 46/50
# 3/3 [==============================] - 0s 8ms/step - loss: 5.0372 - val_loss: 4.9829
# Epoch 47/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0313 - val_loss: 4.9758
# Epoch 48/50
# 3/3 [==============================] - 0s 8ms/step - loss: 5.0241 - val_loss: 4.9673
# Epoch 49/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0166 - val_loss: 4.9595
# Epoch 50/50
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0097 - val_loss: 4.9522

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨

predictions = Asy_autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
#        reconstruction_error
# count            288.000000
# mean               5.037700
# std                0.307719
# min                4.543342
# 25%                4.789878
# 50%                5.054048
# 75%                5.184409
# max                6.907825

# %%
error_df.head()
# Out:
#       reconstruction_error true_class
# 1128              5.347352          0
# 1565              5.187739          0
# 1508              5.168948          0
# 1025              5.411105          0
# 1588              5.187317          0

# %%
# threshold 값을 조정하여 최선의 정확도를 얻음, 그래프로를 보고 결정

threshold = 5

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Abnormal" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
error_df['true_class'] = error_df['true_class'].astype(int)

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.61      0.73       195
#            1       0.52      0.89      0.66        93
#
#     accuracy                           0.70       288
#    macro avg       0.72      0.75      0.70       288
# weighted avg       0.79      0.70      0.71       288
